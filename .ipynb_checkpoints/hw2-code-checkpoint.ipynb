# %% [markdown]
# # DATA 512 - Homework 2: Considering Bias in Data

# %% [markdown]
# The goal of this assignment is to explore the concept of bias in data using Wikipedia articles. This assignment will consider articles on political figures from different countries.
#
# We will perform 3 main steps in the course of this notebook:
# 1. Data Acquisition
# 2. Data Processing
# 3. Data Analysis

# %%
#importing relavant libraries
import pandas as pd
import requests
import json
import time
import os

# %% [markdown]
# ## 1. Data Acquisition

# %% [markdown]
# ### Overview
# We will first acquire the raw data provided to us.
# In this section, we load the dataset containing information about politicians and extract relevant Wikipedia page titles from the URLs. The goal is to prepare the data for subsequent API requests to gather additional information.
#
#
# Then we will make API requests to the MediaWiki API to retrieve the current revision IDs for each politician's article. These IDs are then used to request quality scores from the ORES API. The processing includes error handling for articles where quality scores cannot be retrieved.
#
# ### Outputs
# - The dataset is successfully loaded from `politicians_by_country_AUG.2024.csv`, displaying the first few rows to verify its structure.
# - A new column, `page_title`, is created by extracting the Wikipedia page titles from the `url` column. This makes sure that we have the necessary identifiers for making API requests later.
# - Each politician's `revision_id` is retrieved and added to the dataset, allowing for accurate reference to the most recent version of their Wikipedia articles.
# - Quality scores are fetched from the ORES API and added to a new column, `quality_score`. This provides insights into the reliability of each article.
# - Articles that do not return a quality score are logged in a separate dataframe, and a CSV file (`missing_scores.csv`) is generated for future reference.
# - The error rate for the score retrieval process is calculated and printed, indicating the proportion of articles that could not be scored, which is crucial for understanding data completeness.

# %%
# Step 1: Read the CSV file containing article data
df = pd.read_csv('politicians_by_country_AUG.2024.csv')

# Display the first few rows to understand the structure
df.head()
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
# Display the first few rows to understand the structure
df.head()

# Step 1: Extract Wikipedia page titles from the 'url' column
df['page_title'] = df['url'].apply(lambda x: x.split("/")[-1])

# Display the updated DataFrame with the extracted page titles
df[['name', 'url', 'page_title']].head()
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#              page_title
# 0        Majah_Ha_Adrif
# 1     Haroon_al-Afghani
# 2           Tayyab_Agha
# 3  Khadija_Zahra_Ahmadi
# 4        Aziza_Ahmadyar

# %% [markdown]
# Here is where you can input your created Wikimedia username, email address and access token for future use. For more information on how to obtain these authentication keys you can follow the steps listed [here](https://www.mediawiki.org/wiki/API:Info).

# %%
USERNAME = ""
email_address = "" 
ACCESS_TOKEN = ""

# %% [markdown]
# This code insantiates some constants that we will be using throughout the functions defined in this code. Revise it as you see fit.

# %%
#    CONSTANTS
#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"


#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.

API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0*60.0)/5000.0)-API_LATENCY_ASSUMED  # The key authorizes 5000 requests per hour

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#    
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "trishp3@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': f"Bearer {ACCESS_TOKEN}"
}

#    This is a template for the parameters that we need to supply in the headers of an API request
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : 'trishp3@uw.edu',         # your email address should go here
    'access_token'  : ACCESS_TOKEN        # the access token you create will need to go here
}

#    This is a template of the data required as a payload when making a scoring request of the ORES model
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

# %% [markdown]
# ### Data Acquisition 1.2: Creating Functions
# In this sections we will create 4 functions to create a dataset of Page Title, Revision IDs, and Article Quality Classifications. I split up my work here as follows:
#
# 1. read each line of politicians_by_country.AUG.2024.csv,
# 2. make a page info request to get the current page revision, and
# 3. make an ORES request using the page title and current revision id.
#
# #### Functions Created:
# - **`request_pageinfo_per_article`** : This function takes a list of Wikipedia page titles as input and makes requests to the MediaWiki API to fetch detailed page information for each title.
# - **`get_current_revision_id`**: This function processes the output from `request_pageinfo_per_article` to extract the current revision ID for each Wikipedia article.
#
# - **`request_ores_score_per_article`**:This function makes API requests to the ORES API to obtain quality scores for each article based on their current revision IDs.
#
# - **`get_ores_quality_score`**:This function processes the output from `request_ores_score_per_article` to organize and extract quality scores for each Wikipedia article.
#
# Finally, we ouptut a file named `ores_quality_scores.csv` with the corresponding Page Quality Scores from the ORES Model, the article title, and the Revision ID from the Wikimedia Page Unfo API.
#
# Parts of these functions were taken and inspired by Dr. David W. McDonald's sample code on *Article Page Info MediaWiki API Example* and *Requesting ORES scores through LiftWing ML Service API*. For links to the sample code please visit the [Github Repository](https://github.com/trishaprasant/data-512-homework_2/tree/main/sample%20code)  or access theses sample code files `wp_ores_liftwing_example.ipynb` and `wp_page_info_example.ipynb`.

# %% [markdown]
# Here I create functions to obtain corresponding Revision ID for each article. The steps I took are as follows:
#
# `request_pageinfo_per_article`:
# - Construct a URL for the MediaWiki API using the given page titles.
# - Send requests to the API and handles responses, collecting relevant data such as the current revision IDs.
# - The collected data is structured into a dataframe.
#
# `get_current_revision_id`:
# - Takes the dataframe returned from the previous function as input.
# - The function isolates the current revision IDs from the metadata and returns them in a structured format

# %%
# Constants
MEDIAWIKI_API_URL = "https://en.wikipedia.org/w/api.php"
API_HEADER_AGENT = 'User-Agent'
API_THROTTLE_WAIT = 0.002  
REQUEST_HEADERS = {
    'User-Agent': "trishp3@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': f"Bearer {ACCESS_TOKEN}"
}

# Template for MediaWiki page info requests
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "prop": "revisions",
    "rvprop": "ids",
    "format": "json",
    "titles": None 
}

def request_pageinfo_per_article(article_title=None, 
                                 endpoint_url=MEDIAWIKI_API_URL, 
                                 request_template=PAGEINFO_PARAMS_TEMPLATE,
                                 headers=REQUEST_HEADERS):
    """This function requests page info for a Wikipedia article using the Page Info API from Wikimedia"""
    
    # Ensure the article title is provided
    if article_title:
        request_template['titles'] = article_title
    else:
        raise Exception("Must supply an article title to make a pageinfo request.")

    # Ensure headers contain the UW email
    if API_HEADER_AGENT not in headers:
        raise Exception(f"The header data should include a '{API_HEADER_AGENT}' field that contains your UW email address.")
    
    if 'uwnetid@uw' in headers[API_HEADER_AGENT]:
        raise Exception(f"Use your UW email address in the '{API_HEADER_AGENT}' field.")

    # Make the request with throttling
    try:
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(f"Error during request: {e}")
        return None
    
    return json_response

def get_current_revision_id(page_title):
    """Function to get the current revision ID for a Wikipedia page"""
    response_data = request_pageinfo_per_article(article_title=page_title)
    
    if response_data:
        pages = response_data.get('query', {}).get('pages', {})
        page_info = next(iter(pages.values()), {})
        
        if 'revisions' in page_info:
            return page_info['revisions'][0]['revid']
    
    return None

# %% [markdown]
# Revision ID example for debugging purposes.

# %%
# Get the first page title from the dataframe
first_page_title = df['page_title'].iloc[0]

# Get the revision ID for the first page title
first_revision_id = get_current_revision_id(first_page_title)
first_revision_id
# Out:
# 1251034492

# %% [markdown]
# Here I create functions to get ORES quality score using the page title and revision ID. The steps I took here are as follows:
#
# `request_ores_score_per_article`:
# - Takes the current revision IDs as input and constructs appropriate requests for the ORES API.
# - Returns the quality scores in a structured format, allowing for easy integration into the main dataset.
#
# `get_ores_quality_score`:
# - Receives the scores from the previous function and organizes them alongside the corresponding page titles and revision IDs.
# - Outputs a complete dataframe containing the article titles, revision IDs, and their respective quality scores for further analysis.

# %%
# Constants
ORES_API_URL = "https://ores.wikimedia.org/v3/scores/enwiki/"
API_THROTTLE_WAIT = 0.002 # Throttle wait time to avoid exceeding request limits


# ORES request data template
ORES_REQUEST_DATA_TEMPLATE = {
    'rev_id': None,  #placeholder
    'model': 'articlequality'
}

def request_ores_score_per_article(article_revid=None, email_address=None, access_token=None,
                                   endpoint_url=ORES_API_URL, 
                                   model_name='articlequality', 
                                   request_data=ORES_REQUEST_DATA_TEMPLATE, 
                                   header_format=REQUEST_HEADER_TEMPLATE):
    """Function to request ORES quality score for a specific article revision"""
    
    # Ensure the necessary parameters are provided
    if article_revid:
        request_data['rev_id'] = article_revid
    else:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    
    if not email_address:
        raise Exception("Must provide an 'email_address' value")
    
    if not access_token:
        raise Exception("Must provide an 'access_token' value")
    
    # Construct request URL
    request_url = f"{endpoint_url}{article_revid}/?models={model_name}"
    
    # Create request headers
    headers = {key: value.format(email_address=email_address, access_token=access_token) 
               for key, value in header_format.items()}
    
    # Make the request with throttling
    try:
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(f"Error during request: {e}")
        return None
    
    return json_response

def get_ores_quality_score(revision_id, email_address, access_token):
    score_data = request_ores_score_per_article(article_revid=revision_id, 
                                                email_address=email_address, 
                                                access_token=access_token)
    
    try:
        return score_data['enwiki']['scores'][str(revision_id)]['articlequality']['score']['prediction']
    except KeyError:
        return None

missing_scores = 0 # Variables to track missing scores
total_articles = len(df)

results = [] # Store the results in a list

# %% [markdown]
# ORES Score Example for debugging purposes:

# %%
ores_score = get_ores_quality_score(first_revision_id, email_address, ACCESS_TOKEN)
print(ores_score)
# Out:
# FA

# %% [markdown]
# In this step we actually perform the Data Acquisiton based on the functions we created. We output a file named

# %%
# Loop through each page, get revision ID and ORES quality score
for i, row in df.iterrows():
    page_title = row['page_title']
    print(f"Processing article {i+1}/{total_articles}: {page_title}")
    
    # Get the revision ID
    revision_id = get_current_revision_id(page_title)
    
    if revision_id:
        # Get the ORES quality score
        score = get_ores_quality_score(revision_id)
        if score:
            results.append({'page_title': page_title, 'revision_id': revision_id, 'quality_score': score})
        else:
            print(f"Could not retrieve score for {page_title}")
            missing_scores += 1
    else:
        print(f"Could not retrieve revision ID for {page_title}")
        missing_scores += 1
    
    # Sleep to avoid overloading the API
    time.sleep(0.5)

# Calculate the error rate
error_rate = missing_scores / total_articles
print(f"Error Rate: {error_rate * 100:.2f}%")

# Save the results to a new CSV file
results_df = pd.DataFrame(results)
results_df.to_csv("ores_quality_scores.csv", index=False)
# Out:
# Processing article 1/7155: Majah_Ha_Adrif
# Processing article 2/7155: Haroon_al-Afghani
# Processing article 3/7155: Tayyab_Agha
# Processing article 4/7155: Khadija_Zahra_Ahmadi
# Processing article 5/7155: Aziza_Ahmadyar
# Processing article 6/7155: Muqadasa_Ahmadzai
# Processing article 7/7155: Mohammad_Sarwar_Ahmedzai
# Processing article 8/7155: Amir_Muhammad_Akhundzada
# Processing article 9/7155: Nasrullah_Baryalai_Arsalai
# Processing article 10/7155: Abdul_Rahim_Ayoubi
# Processing article 11/7155: Ismael_Balkhi
# Processing article 12/7155: Abdul_Baqi_Turkistani
# Processing article 13/7155: Mohammad_Ghous_Bashiri
# Processing article 14/7155: Jan_Baz
# Processing article 15/7155: Bashir_Ahmad_Bezan
# Processing article 16/7155: Rafiullah_Bidar
# Processing article 17/7155: Mohammad_Siddiq_Chakari
# Processing article 18/7155: Cheragh_Ali_Cheragh
# Processing article 19/7155: Nasir_Ahmad_Durrani
# Processing article 20/7155: Muhammad_Hashim_Esmatullahi
# Processing article 21/7155: Ezatullah_(Nangarhar)
# Processing article 22/7155: Aimal_Faizi
# Processing article 23/7155: Gajinder_Singh_Safri
# Processing article 24/7155: Sharif_Ghalib
# Processing article 25/7155: Hashmat_Ghani_Ahmadzai
# Processing article 26/7155: Abdul_Ghani_Ghani
# Processing article 27/7155: Ghulam_Ghaus
# Processing article 28/7155: Ghulam_Muhammad_Ghobar
# Processing article 29/7155: Mohammad_Gul_(Helmand_Council)
# Processing article 30/7155: Sayed_Yousuf_Halim
# Processing article 31/7155: Rangina_Hamidi
# Processing article 32/7155: Sayed_Zafar_Hashemi
# Processing article 33/7155: Qutbuddin_Hilal
# Processing article 34/7155: Mahboba_Hoqomal
# Processing article 35/7155: Musa_Hotak
# Processing article 36/7155: Mirza_Muhammad_Ismail
# Processing article 37/7155: Sayed_Jalal
# Processing article 38/7155: Said_Tayeb_Jawad
# Processing article 39/7155: Sayed_Jalal_Karim
# Processing article 40/7155: Hafizullah_Shabaz_Khail
# Processing article 41/7155: Masoud_Khalili
# Processing article 42/7155: Mohammad_Khan_(athlete)
# Processing article 43/7155: Samoud_Khan
# Processing article 44/7155: Baran_Khan_Kudezai
# Processing article 45/7155: Azizullah_Lodin
# Processing article 46/7155: Razaq_Mamoon
# Processing article 47/7155: Fazel_Ahmed_Manawi
# Processing article 48/7155: Moeen_Marastial
# Processing article 49/7155: Ahmad_Wali_Massoud
# Processing article 50/7155: Mohammad_Daud_Miraki
# Processing article 51/7155: Abdul_Sattar_Mirzakwal
# Processing article 52/7155: Abdul_Karim_Misaq
# Processing article 53/7155: Ali_Mohammad_(politician)
# Processing article 54/7155: Nasruddin_Mohseni
# Processing article 55/7155: Davood_Moradian
# Processing article 56/7155: Zalmai_Mujadidi
# Processing article 57/7155: Sardar_Mohammad_Nadir_Naeem
# Processing article 58/7155: Daoud_Naji
# Processing article 59/7155: Gholam_Rabani_Nasher
# Processing article 60/7155: Ghulam_Faroq_Nijrabi
# Processing article 61/7155: Zabih-U-llah_Ghazi_Noristani
# Processing article 62/7155: Mohammed_Tahir_Omar
# Processing article 63/7155: Mohammed_Qalamuddin
# Processing article 64/7155: Ghulam_Mohammad_Rigi
# Processing article 65/7155: Ghulam_Hassan_Safi
# Processing article 66/7155: Hanifa_Safi
# Processing article 67/7155: Mohammed_Zia_Salehi
# Processing article 68/7155: Abdul_Majid_Samim
# Processing article 69/7155: Saber_Sangar
# Processing article 70/7155: Sayed_Nasim_Mihanparast
# Processing article 71/7155: Suhail_Shaheen
# Processing article 72/7155: Fazal_Hadi_Shinwari
# Processing article 73/7155: Baktash_Siawash
# Processing article 74/7155: Hasan_Ali_Sultani
# Processing article 75/7155: Mohammad_Hashem_Taufiqui
# Processing article 76/7155: Pacha_Gul_Wafadar
# Processing article 77/7155: Wahidullah_Waissi
# Processing article 78/7155: Ahmadullah_Wasiq
# Processing article 79/7155: Gul_Ahmmad_Yama
# Processing article 80/7155: Abdul_Salam_Zaeef
# Processing article 81/7155: Abdul_Zahir_(Konar_Education_Minister)
# Processing article 82/7155: Mohammed_Zaman
# Processing article 83/7155: Ziauddin_(Afghan_militia_leader)
# Processing article 84/7155: Qari_Ziauddin
# Processing article 85/7155: Abdul_Ghafor_Zori
# Processing article 86/7155: Ali_Pasha_of_Gusinje
# Processing article 87/7155: Ylli_Asllani
# Processing article 88/7155: Azis_Tahir_Ajdonati
# Processing article 89/7155: Bislim_Bajgora
# Processing article 90/7155: Kastriot_Berissa
# Processing article 91/7155: Bardhok_Biba
# Processing article 92/7155: Kostandin_Boshnjaku
# Processing article 93/7155: Spartak_Braho
# Processing article 94/7155: Safet_Butka
# Processing article 95/7155: Uran_Butka
# Processing article 96/7155: Refo_Çapari
# Processing article 97/7155: Neritan_Ceka
# Processing article 98/7155: Hysni_Curri
# Processing article 99/7155: Ibrahim_Dalliu
# Processing article 100/7155: Niazi_Demi
# Processing article 101/7155: Abdurrahman_Dibra
# Processing article 102/7155: Bujar_Dida
# Processing article 103/7155: Ahmed_Dino
# Processing article 104/7155: Rasih_Dino
# Processing article 105/7155: Ferhat_Bey_Draga
# Processing article 106/7155: Nexhip_Draga
# Processing article 107/7155: Aqif_Pasha_Elbasani
# Processing article 108/7155: Abas_Ermenji
# Processing article 109/7155: Qamil_Musa_Haxhi_Feza
# Processing article 110/7155: Themistokli_Gërmenji
# Processing article 111/7155: Sabri_Godo
# Processing article 112/7155: Mihal_Grameno
# Processing article 113/7155: Aćif_Hadžiahmetović
# Processing article 114/7155: High_Council_of_Regency
# Processing article 115/7155: Kurt_Agë_Kadiu
# Processing article 116/7155: Mehmed_Kalakula
# Processing article 117/7155: Alfred_Karamuço
# Processing article 118/7155: Ibrahim_Karbunara
# Processing article 119/7155: Ali_Këlcyra
# Processing article 120/7155: Bajram_Kelmendi
# Processing article 121/7155: Kristo_Kirka
# Processing article 122/7155: Elez_Koçi
# Processing article 123/7155: Xhelal_Koprëncka
# Processing article 124/7155: Kryeziu_family
# Processing article 125/7155: Artur_Kuko
# Processing article 126/7155: Xhavid_Leskoviku
# Processing article 127/7155: Sabit_Lulo
# Processing article 128/7155: Gjon_Markagjoni
# Processing article 129/7155: Tefik_Mborja
# Processing article 130/7155: Hysni_Milloshi
# Processing article 131/7155: Musa_Qazimi
# Processing article 132/7155: Mustafa_Ndroqi
# Processing article 133/7155: Behxhet_Nepravishta
# Processing article 134/7155: Adrian_Neritani
# Processing article 135/7155: Sali_Nivica
# Processing article 136/7155: Thoma_Orologa
# Processing article 137/7155: Bedri_Pejani
# Processing article 138/7155: Kadri_Prishtina
# Processing article 139/7155: Ymer_Prizreni
# Processing article 140/7155: Avni_Rustemi
# Processing article 141/7155: Chatin_Sarachi
# Processing article 142/7155: Nebi_Sefa
# Processing article 143/7155: Eduard_Shalsi
# Processing article 144/7155: Ylli_Vesel_Shehu
# Processing article 145/7155: Athanas_Shundi
# Processing article 146/7155: Xhelal_Sveçla
# Processing article 147/7155: Mehmet_Tahsini
# Processing article 148/7155: Ibrahim_Temo
# Processing article 149/7155: Afrim_Tole
# Processing article 150/7155: Syreja_Vlora
# Processing article 151/7155: Visarion_Xhuvani
# Processing article 152/7155: Visar_Ymeri
# Processing article 153/7155: Abdyl_Ypi
# Processing article 154/7155: Xhezair_Zaganjori
# Processing article 155/7155: Menduh_Zavalani
# Processing article 156/7155: Abdelkader_Zoukh
# Processing article 157/7155: Chaâbane_Aït_Abderrahim
# Processing article 158/7155: Ali_Aoun
# Processing article 159/7155: Basma_Azouar
# Processing article 160/7155: Mohamed_Seghir_Babes
# Processing article 161/7155: Noureddine_Bahbouh
# Processing article 162/7155: Lamine_Bechichi
# Processing article 163/7155: Aïssa_Bekkai
# Processing article 164/7155: Abdelhakim_Belabed
# Processing article 165/7155: Mohamed_Tarek_Belaribi
# Processing article 166/7155: Kamel_Beldjoud
# Processing article 167/7155: Aboubakr_Belkaid
# Processing article 168/7155: Youcef_Belmehdi
# Processing article 169/7155: Mohamed_Cherif_Belmihoub
# Processing article 170/7155: Mohamed_Belouizdad
# Processing article 171/7155: Benaouda_Hadj_Hacène_Bachterzi
# Processing article 172/7155: Souad_Bendjaballah
# Processing article 173/7155: Abdelkrim_Benmbarek
# Processing article 174/7155: Mohamed_Bensalam
# Processing article 175/7155: Fayçal_Bentaleb
# Processing article 176/7155: Ahmed_Bidani
# Processing article 177/7155: Kamel_Bidari
# Processing article 178/7155: Rachid_Bladehane
# Processing article 179/7155: Saïd_Boualam
# Processing article 180/7155: Rabah_Bouaziz
# Processing article 181/7155: Abdeslam_Bouchouareb
# Processing article 182/7155: Ibrahim_Boughali
# Processing article 183/7155: Yahia_Boukhari
# Processing article 184/7155: Mohamed_Bouslimani
# Processing article 185/7155: Foued_Chehat
# Processing article 186/7155: Hamza_Al_Sid_Cheikh
# Processing article 187/7155: Hocine_Cherhabil
# Processing article 188/7155: Abderrahmane_Meziane_Chérif
# Processing article 189/7155: Saïd_Chibane
# Processing article 190/7155: Brahim_Chibout
# Processing article 191/7155: Youcef_Chorfa
# Processing article 192/7155: Fazia_Dahleb
# Processing article 193/7155: Taha_Derbal
# Processing article 194/7155: Nassim_Diafat
# Processing article 195/7155: Mokhtar_Didouche
# Processing article 196/7155: Bouras_Djamel
# Processing article 197/7155: Fatiha_Serour
# Processing article 198/7155: Ahmed_Hamiani
# Processing article 199/7155: Nadir_Kassab
# Processing article 200/7155: Brahim_Djamel_Kassali
# Processing article 201/7155: Kaoutar_Krikou
# Processing article 202/7155: Sassi_Lamouri
# Processing article 203/7155: Mohamed_Maghlaoui
# Processing article 204/7155: Amar_Makhloufi
# Processing article 205/7155: Yassine_Merabi
# Processing article 206/7155: Brahim_Merad
# Processing article 207/7155: Bachir_Messaitfa
# Processing article 208/7155: Azzedine_Mihoubi
# Processing article 209/7155: Mohamed_Ali_Boughazi
# Processing article 210/7155: Amar_Mohammedi
# Processing article 211/7155: Samia_Moualfi
# Processing article 212/7155: Soraya_Mouloudji
# Processing article 213/7155: Yacine_Oualid
# Processing article 214/7155: Cherif_Rahmani
# Processing article 215/7155: Lakhdar_Rakhroukh
# Processing article 216/7155: Laid_Rebiga
# Processing article 217/7155: Kamel_Rezig
# Processing article 218/7155: Salim_Saadi
# Processing article 219/7155: Abdelhak_Saihi
# Processing article 220/7155: Hichem_Sofiane_Salaouatchi
# Processing article 221/7155: Naima_Salhi
# Processing article 222/7155: Abderezak_Sebgag
# Processing article 223/7155: Abderrachid_Tabbi
# Processing article 224/7155: Karim_Bibi_Triki
# Processing article 225/7155: Layachi_Yaker
# Processing article 226/7155: Ahmed_Zeghdar
# Processing article 227/7155: Adão_Francisco_Correia_de_Almeida
# Processing article 228/7155: Ana_Paula_Chantre_Luna_de_Carvalho
# Processing article 229/7155: Alexandre_Sebastião_André
# Processing article 230/7155: Paulino_Baptista
# Processing article 231/7155: Bernarda_Gonçalves_Martins
# Processing article 232/7155: João_Baptista_Borges
# Processing article 233/7155: Carolina_Cerqueira
# Processing article 234/7155: Arlete_Chimbinda
# Processing article 235/7155: Kafundanga_Chingunji
# Processing article 236/7155: Jeremias_Chitunda
# Processing article 237/7155: Abel_Chivukuvuku
# Processing article 238/7155: Fiel_Domingos_Constantino
# Processing article 239/7155: Adalberto_Costa_Júnior
# Processing article 240/7155: Adjany_Costa
# Processing article 241/7155: Álvaro_Arnaldo_Craveiro
# Processing article 242/7155: Raul_Danda
# Processing article 243/7155: Diamantino_Pedro_Azevedo
# Processing article 244/7155: Faustina_Fernandes_Inglês_de_Almeida_Alves
# Processing article 245/7155: Abraão_Gourgel
# Processing article 246/7155: Jofre_Van-Dúnem_Júnior
# Processing article 247/7155: José_Carvalho_da_Rocha
# Processing article 248/7155: José_Luis_de_Matos
# Processing article 249/7155: Kambamba_Kulaxingo
# Processing article 250/7155: Jesus_Faria_Maiato
# Processing article 251/7155: Manuel_Neto_da_Costa
# Processing article 252/7155: Manuel_Tavares_de_Almeida
# Processing article 253/7155: Marcos_Alexandre_Nhunga
# Processing article 254/7155: Maria_Cândida_Pereira_Teixeira
# Processing article 255/7155: Maria_do_Rosário_Teixeira_de_Alva_Sequeira_Bragança_Sambo
# Processing article 256/7155: David_Mendes
# Processing article 257/7155: Saíde_Mingas
# Processing article 258/7155: Fernando_Faustino_Muteka
# Processing article 259/7155: Pedro_Mutinde
# Processing article 260/7155: José_Ndele
# Processing article 261/7155: Ana_Paula_Sacramento_Neto
# Processing article 262/7155: Daniel_Ntongi-Nzinga
# Processing article 263/7155: Paula_Cristina_Francisco_Coelho
# Processing article 264/7155: Pedro_Pedalé
# Processing article 265/7155: Elias_Salupeto_Pena
# Processing article 266/7155: Johnny_Eduardo_Pinnock
# Processing article 267/7155: Santana_André_Pitra
# Processing article 268/7155: Francisco_Manuel_Monteiro_de_Queiróz
# Processing article 269/7155: José_Aníbal_Lopes_Rocha
# Processing article 270/7155: José_da_Rocha
# Processing article 271/7155: Rosa_Luís_de_Sousa_Micolo
# Processing article 272/7155: Luís_Gomes_Sambo
# Processing article 273/7155: Branca_Manuel_Espirito_Santo
# Processing article 274/7155: João_Ernesto_dos_Santos
# Processing article 275/7155: José_Filomeno_dos_Santos
# Processing article 276/7155: Jonas_Savimbi
# Processing article 277/7155: Pinda_Simão
# Processing article 278/7155: Manuel_Bernardo_de_Sousa
# Processing article 279/7155: Augusto_da_Silva_Tomás
# Processing article 280/7155: José_Jacinto_Van-Dúnem
# Processing article 281/7155: José_Vieira_Dias_Van-Dúnem
# Processing article 282/7155: Luzia_Inglês_Van-Dúnem
# Processing article 283/7155: Manuel_Vicente
# Processing article 284/7155: Mfulupinga_Nlando_Victor
# Processing article 285/7155: Clement_Antonio
# Processing article 286/7155: Randolph_Beazer
# Processing article 287/7155: Studiation_Brown
# Processing article 288/7155: Alex_Browne_(politician)
# Processing article 289/7155: Colin_O'Neil_Browne
# Processing article 290/7155: James_Carlisle
# Processing article 291/7155: Gail_Christian
# Processing article 292/7155: Mackenzie_Frank
# Processing article 293/7155: Osbert_Richard_Frederick
# Processing article 294/7155: Caleb_Gardiner
# Processing article 295/7155: Shenella_Mary_Shadida_Govia
# Processing article 296/7155: William_Haynes-Smith
# Processing article 297/7155: Tim_Hector
# Processing article 298/7155: Cheryl_Mary_Clare_Hurst
# Processing article 299/7155: Wilfred_Jacobs
# Processing article 300/7155: Rick_James_(actor)
# Processing article 301/7155: Kiz_Johnson
# Processing article 302/7155: Fabian_Jones
# Processing article 303/7155: Johnathan_Joseph_(politician)
# Processing article 304/7155: Kelvin_Simon
# Processing article 305/7155: Harold_Lovell
# Processing article 306/7155: Edmond_Mansoor
# Processing article 307/7155: David_Massiah
# Processing article 308/7155: Joanne_Massiah
# Processing article 309/7155: Dwayne_George
# Processing article 310/7155: Knacyntar_Nedd
# Processing article 311/7155: Melford_Nicholas
# Processing article 312/7155: Shawn_Nicholas
# Processing article 313/7155: Bernard_Percival
# Processing article 314/7155: Jamale_Pringle
# Processing article 315/7155: Philip_Shoul
# Processing article 316/7155: Rawdon_Turner
# Processing article 317/7155: Alincia_Williams-Grant
# Processing article 318/7155: Juan_Alemann
# Processing article 319/7155: Germán_Alfaro
# Processing article 320/7155: Joaquín_Samuel_de_Anchorena
# Processing article 321/7155: Juan_Agustín_Augier
# Processing article 322/7155: Uladislao_Augier
# Processing article 323/7155: Marco_Aurelio_Avellaneda
# Processing article 324/7155: Joaquín_Belgrano
# Processing article 325/7155: Antonio_Bermejo
# Processing article 326/7155: Antonio_Beruti
# Processing article 327/7155: Héctor_Bidonde
# Processing article 328/7155: Silvano_Bores
# Processing article 329/7155: Exequiel_Bustillo
# Processing article 330/7155: Mario_Cafiero
# Processing article 331/7155: Alberto_Manuel_Campos
# Processing article 332/7155: Alejo_Castex
# Processing article 333/7155: Dámaso_Centeno
# Processing article 334/7155: Rossana_Chahla
# Processing article 335/7155: Lázaro_Chiappe
# Processing article 336/7155: Carlos_Corach
# Processing article 337/7155: Jorge_Coscia
# Processing article 338/7155: Carlos_de_la_Rosa
# Processing article 339/7155: Juan_Carlos_Del_Bello
# Processing article 340/7155: Luis_L._Domínguez
# Processing article 341/7155: Máximo_Etchecopar
# Processing article 342/7155: Héctor_Toty_Flores
# Processing article 343/7155: Guillermo_Francos
# Processing article 344/7155: Juan_Fugl
# Processing article 345/7155: Santiago_Gallo
# Processing article 346/7155: Manuel_José_García
# Processing article 347/7155: Juan_José_Gómez_Centurión
# Processing article 348/7155: Luis_Carlos_Gómez_Centurión
# Processing article 349/7155: Martín_Guzmán
# Processing article 350/7155: Federico_Helguera
# Processing article 351/7155: Fernando_Iglesias_(Argentine_politician)
# Processing article 352/7155: Ricardo_Kennedy
# Processing article 353/7155: Carlos_Kunkel
# Processing article 354/7155: Norberto_La_Porta
# Processing article 355/7155: Andrés_Larroque
# Processing article 356/7155: Julián_de_Leyva
# Processing article 357/7155: Mónica_López_(politician)
# Processing article 358/7155: Lucio_Victorio_Mansilla
# Processing article 359/7155: Nicolás_Massot
# Processing article 360/7155: Martín_Menem
# Processing article 361/7155: Juan_Mignaburu
# Processing article 362/7155: Guillermo_Montenegro
# Processing article 363/7155: Mariano_Moreno
# Processing article 364/7155: Marcelo_Muniagurria
# Processing article 365/7155: Fernando_Nadra
# Processing article 366/7155: Rómulo_Sebastián_Naón
# Processing article 367/7155: Santiago_G._O'Farrell
# Processing article 368/7155: Alfredo_Olmedo
# Processing article 369/7155: Miguel_Ángel_Pesce
# Processing article 370/7155: Carlos_Petroni
# Processing article 371/7155: Alejo_Peyret
# Processing article 372/7155: Aldo_Pignanelli
# Processing article 373/7155: Abel_Posse
# Processing article 374/7155: Enrique_S._Quintana
# Processing article 375/7155: Amán_Rawson
# Processing article 376/7155: Martín_Sabbatella
# Processing article 377/7155: Juan_Pablo_Schiavi
# Processing article 378/7155: Héctor_Tizón
# Processing article 379/7155: Claudio_Uberti
# Processing article 380/7155: Arístides_Villanueva
# Processing article 381/7155: Jorge_Yoma
# Processing article 382/7155: Ashot_Arsenyan
# Processing article 383/7155: Vigen_Chitechyan
# Processing article 384/7155: Hayk_Chobanyan
# Processing article 385/7155: Gurgen_Egiazaryan
# Processing article 386/7155: Parunak_Ferukhan
# Processing article 387/7155: Gevorg_Ghazaryan_(politician)
# Processing article 388/7155: Andrias_Ghukasyan
# Processing article 389/7155: Aram_Grigoryan_(politician)
# Processing article 390/7155: Vahagn_Hovakimyan
# Processing article 391/7155: Tigran_Karapetyan
# Processing article 392/7155: Tigran_Khzmalyan
# Processing article 393/7155: Mikayel_Kotanyan
# Processing article 394/7155: Hrant_Maloyan
# Processing article 395/7155: Khachatur_Malumian
# Processing article 396/7155: Aram_Manukyan
# Processing article 397/7155: Gevorg_Melik-Karagyozyan
# Processing article 398/7155: Vahan_Minakhoryan
# Processing article 399/7155: Ruben_Miroyan
# Processing article 400/7155: Ruben_Mirzakhanyan
# Processing article 401/7155: Badal_Muradyan
# Processing article 402/7155: Narine_Tukhikyan
# Processing article 403/7155: Gabriel_Noradoungian
# Processing article 404/7155: Israel_Ori
# Processing article 405/7155: Paul_Paul
# Processing article 406/7155: Garo_Paylan
# Processing article 407/7155: Genrikh_Poghosyan
# Processing article 408/7155: Ishkhan_Saghatelyan
# Processing article 409/7155: Karen_Sargsyan_(sociologist)
# Processing article 410/7155: Martiros_Sarukhanyan
# Processing article 411/7155: Vartkes_Serengülian
# Processing article 412/7155: Suren_Shadunts
# Processing article 413/7155: Ohannes_Tchekidjian
# Processing article 414/7155: Hrayr_Tovmasyan
# Processing article 415/7155: Usub_Bek_Temuryan
# Processing article 416/7155: Kegham_Vanigian
# Processing article 417/7155: Serop_Zakaryan
# Processing article 418/7155: Alfons_Adam
# Processing article 419/7155: Ingo_Appelt
# Processing article 420/7155: Maximilian_Anton_Karl,_Count_Baillet_de_Latour
# Processing article 421/7155: Heinrich_Alfred_Barb
# Processing article 422/7155: Leopold_Berchtold
# Processing article 423/7155: Joseph_Buttinger
# Processing article 424/7155: Prince_Carl_of_Solms-Braunfels
# Processing article 425/7155: Count_Václav_Antonín_Chotek_of_Chotkov_and_Vojnín
# Processing article 426/7155: Citizens'_Ministry
# Processing article 427/7155: Richard_von_Coudenhove-Kalergi
# Processing article 428/7155: Franz_Dinghofer
# Processing article 429/7155: George_Abraham_von_Dyhrn
# Processing article 430/7155: Eduard_von_Grebmer_zu_Wolfsthurn
# Processing article 431/7155: Barbara_Eibinger-Miedl
# Could not retrieve revision ID for Barbara_Eibinger-Miedl
# Processing article 432/7155: Hans_Ferlitsch
# Processing article 433/7155: Friedhelm_Frischenschlager
# Processing article 434/7155: Walter_Guggenberger
# Processing article 435/7155: Ulrich_Habsburg-Lothringen
# Processing article 436/7155: Ernst_Hampel_(politician)
# Processing article 437/7155: Hans_Peter_Haselsteiner
# Processing article 438/7155: Friedrich_Wilhelm_von_Haugwitz
# Processing article 439/7155: Eduard_Hedvicek
# Processing article 440/7155: Hermann_Stern
# Processing article 441/7155: Jürgen_Himmelbauer
# Processing article 442/7155: Anton_Hofer
# Processing article 443/7155: Andreas_Hörtnagl
# Processing article 444/7155: Franz_Jetzinger
# Processing article 445/7155: Konstantin_Jireček
# Processing article 446/7155: Hugo_Jury
# Processing article 447/7155: Joseph_Kenner
# Processing article 448/7155: Theodor_Kery
# Processing article 449/7155: Michael_Killisch-Horn
# Processing article 450/7155: Sophia_Kircher
# Processing article 451/7155: Hubert_Klausner
# Processing article 452/7155: Martin_Kocher
# Processing article 453/7155: Józef_Kożdoń
# Processing article 454/7155: Gottfried_von_Kühnelt-Leddihn
# Processing article 455/7155: Franz_Leitner_(politician)
# Processing article 456/7155: Elmar_Lichtenegger
# Processing article 457/7155: Julius_Lippert_(historian)
# Processing article 458/7155: Reinhold_Lopatka
# Processing article 459/7155: Karl_Lütgendorf
# Processing article 460/7155: Jürgen_Mandl
# Processing article 461/7155: Renate_Mann
# Processing article 462/7155: Ferdinand_Mannlicher
# Processing article 463/7155: Christoph_Matznetter
# Processing article 464/7155: Johann_Gregor_Memhardt
# Processing article 465/7155: Franz_Moroder
# Processing article 466/7155: Heinz_Nittel
# Processing article 467/7155: Heidemaria_Onodi
# Processing article 468/7155: Brigitta_Pallauf
# Processing article 469/7155: Wladimir_von_Pawlowski
# Processing article 470/7155: Johann_Anton_von_Pergen
# Processing article 471/7155: Gerhard_Pfanzelter
# Processing article 472/7155: Walter_Pfrimer
# Processing article 473/7155: Leopold_Poetsch
# Processing article 474/7155: Thomas_Prinzhorn
# Processing article 475/7155: Gregor_Razumovsky_(activist)
# Processing article 476/7155: Horst_Rosenkranz
# Processing article 477/7155: Emil_Sax
# Processing article 478/7155: Peter_Schieder
# Processing article 479/7155: Karl_Schmitzer
# Processing article 480/7155: Sonja_Zwazl
# Processing article 481/7155: Georg_Adam,_Prince_of_Starhemberg
# Processing article 482/7155: Gundaker_Thomas_Starhemberg
# Processing article 483/7155: Josef_Staribacher
# Processing article 484/7155: Peter_Strasser_(politician)
# Processing article 485/7155: Julius_Tandler
# Processing article 486/7155: Leopold,_Count_von_Thun_und_Hohenstein
# Processing article 487/7155: Karl_Freiherr_von_Vogelsang
# Processing article 488/7155: Anton_von_Winzor
# Processing article 489/7155: Gisela_Wurm
# Processing article 490/7155: Alexander_Zach
# Processing article 491/7155: Curt_Franz_Wenzel_Christoph_Erdmann_Graf_Zedtwitz_von_Moraván_und_Duppau
# Processing article 492/7155: Karl_von_Zinzendorf
# Processing article 493/7155: Muzamil_Abdullayev
# Processing article 494/7155: Leyla_Abdullayeva
# Processing article 495/7155: Elchin_Afandiyev
# Processing article 496/7155: Fazail_Agamali
# Processing article 497/7155: Aliabbas_Salahzade
# Processing article 498/7155: Enver_Alikhanov
# Processing article 499/7155: Tarlan_Aliyarbayov
# Processing article 500/7155: Dilara_Aliyeva
# Processing article 501/7155: Araz_Alizadeh
# Processing article 502/7155: Ali_Asadov
# Processing article 503/7155: Ashraf_Bey_Taghiyev
# Processing article 504/7155: Chimnaz_Aslanova
# Processing article 505/7155: Akram_Aylisli
# Processing article 506/7155: Sahil_Babayev
# Processing article 507/7155: Huseyngulu_Baghirov
# Processing article 508/7155: Bakhish_bey_Rustambeyov
# Processing article 509/7155: Alovsat_Bakhshiyev
# Processing article 510/7155: Mirgasim_Cheshmazer
# Processing article 511/7155: Vilayat_Eyvazov
# Processing article 512/7155: Abdurrahman_Fatalibeyli
# Processing article 513/7155: Fazail_Ibrahimli
# Processing article 514/7155: Afshan_Gadimbeyova
# Processing article 515/7155: Garib_Karimoğlu
# Processing article 516/7155: Gudrat_Gasanguliev
# Processing article 517/7155: Mehrali_Gasimov
# Could not retrieve revision ID for Mehrali_Gasimov
# Processing article 518/7155: Solomon_Grobshtein
# Processing article 519/7155: Teymur_Guliyev
# Processing article 520/7155: Mammad_Gurbanov
# Processing article 521/7155: Musa_Hacigasimov
# Processing article 522/7155: Asaf_Hajiyev
# Processing article 523/7155: Haji_Molla_Ahmad_Nuruzade
# Processing article 524/7155: Farhad_Hajiyev
# Processing article 525/7155: Hasan_Majidov
# Processing article 526/7155: Hasan_Hasanli
# Processing article 527/7155: Jamil_Hasanli
# Processing article 528/7155: Ali_M._Hasanov
# Processing article 529/7155: Zakir_Hasanov
# Processing article 530/7155: Ali_Huseynli
# Processing article 531/7155: Alisahib_Huseynov
# Processing article 532/7155: Ali_Ibrahimov
# Processing article 533/7155: Irshad_Aliyev
# Processing article 534/7155: Mamed_Iskenderov
# Processing article 535/7155: Vidadi_Isgandarov
# Processing article 536/7155: Ajdar_Ismailov
# Processing article 537/7155: Saftar_Jafarov
# Processing article 538/7155: Jeyhun_Jalilov
# Processing article 539/7155: Arastun_Javadov
# Processing article 540/7155: Rovshan_Javadov
# Processing article 541/7155: Anar_Karimov
# Processing article 542/7155: Boris_Kevorkov
# Processing article 543/7155: Gurban_Khalilov
# Processing article 544/7155: Ahmad_Kordary
# Processing article 545/7155: Lutfali_bey_Behbudov
# Processing article 546/7155: Ilham_Madatov
# Processing article 547/7155: Makhmud_Mamed-Guliev
# Processing article 548/7155: Majnun_Mammadov
# Processing article 549/7155: Musa_Mammadov
# Processing article 550/7155: Ramin_Mammadov
# Processing article 551/7155: Elshad_Mirbashir_oghlu
# Processing article 552/7155: Tahir_Mirkishili
# Processing article 553/7155: Movsum_Samadov
# Processing article 554/7155: Fuad_Naghiyev
# Processing article 555/7155: Eldar_Namazov
# Processing article 556/7155: Namig_Nasrullayev
# Processing article 557/7155: Siyavush_Novruzov
# Processing article 558/7155: Zahid_Oruj
# Processing article 559/7155: Sadig_Rahimov
# Processing article 560/7155: Suleyman_Rahimov
# Processing article 561/7155: Huseyn_Rahmanov
# Processing article 562/7155: Rovshen_Rzayev
# Processing article 563/7155: Hasan_Seyidov
# Processing article 564/7155: Hasan_Seyidov_(scientist)
# Processing article 565/7155: Parviz_Shahbazov
# Processing article 566/7155: Mammad_agha_Shahtakhtinski
# Processing article 567/7155: Abid_Sharifov
# Processing article 568/7155: Shirali_Akhundov
# Processing article 569/7155: Ikhtiyar_Shirinov
# Processing article 570/7155: Bakhtiyar_Vahabzadeh
# Processing article 571/7155: Vugar_Mustafayev_(minister)
# Processing article 572/7155: Yusif_Ziya_Talibzadeh
# Processing article 573/7155: Nurali_Yusifbayli
# Processing article 574/7155: Keith_Bell_(Bahamian_politician)
# Processing article 575/7155: Charles_Carter_(Bahamian_journalist)
# Processing article 576/7155: Harold_Christie
# Processing article 577/7155: Timothy_Donaldson
# Processing article 578/7155: Eugene_Dupuch
# Processing article 579/7155: Joseph_Robert_Love
# Processing article 580/7155: McKell_Bonaby
# Processing article 581/7155: Pakesia_Parker-Edgecombe
# Processing article 582/7155: James_Carmichael_Smith_(postmaster)
# Processing article 583/7155: Mohammed_Isa_Al_Abbasi
# Processing article 584/7155: Abdulla_Adel_Fakhro
# Processing article 585/7155: Abdullah_bin_Isa_Al_Khalifa
# Processing article 586/7155: Ahmed_Behzad_(Bahrain)
# Processing article 587/7155: Kamal_Ahmed_(politician)
# Processing article 588/7155: Mohamed_Ali_Hasan_Ali
# Processing article 589/7155: Khalid_Almoayed
# Processing article 590/7155: Aymen_Tawfeeq_Almoayed
# Processing article 591/7155: Nazar_Al_Baharna
# Processing article 592/7155: Mahmood_Al_Bahrani
# Processing article 593/7155: Ammar_Al_Bannai
# Processing article 594/7155: Jawad_Fairooz
# Processing article 595/7155: Qasim_Fakhro
# Processing article 596/7155: Faisal_al-Hamar
# Processing article 597/7155: Nabeel_bin_Yaqub_Al-Hamar
# Processing article 598/7155: Isa_bin_Abdulrahman_Al_Hammadi
# Processing article 599/7155: Jameel_Humadan
# Processing article 600/7155: Isa_bin_Ibrahim_Al_Khalifa
# Processing article 601/7155: Fahmi_al-Jowder
# Processing article 602/7155: Saud_Kanoo
# Processing article 603/7155: Essam_Khalaf
# Processing article 604/7155: Abdullah_bin_Hamad_bin_Isa_Al_Khalifa
# Processing article 605/7155: Ahmed_bin_Mohamed_Al_Khalifa
# Processing article 606/7155: Ali_bin_Khalifa_Al_Khalifa
# Processing article 607/7155: Hala_bint_Mohammed_Al_Khalifa
# Processing article 608/7155: Ibrahim_ibn_Khalifa_Al_Khalifa
# Processing article 609/7155: Mai_bint_Mohammed_Al_Khalifa
# Processing article 610/7155: Salman_bin_Khalifa_Al_Khalifa
# Processing article 611/7155: Hamad_Al_Kooheji
# Processing article 612/7155: Abdullatif_Al-Mahmood
# Processing article 613/7155: Rasheed_Mohammed_Al_Maraj
# Processing article 614/7155: Khalid_Al_Maskati
# Processing article 615/7155: Abdulhussain_bin_Ali_Mirza
# Processing article 616/7155: Mohammed_Al-Buainain
# Processing article 617/7155: Mohammed_bin_Khalifa_bin_Ahmed
# Processing article 618/7155: Mohammed_bin_Khalifa_bin_Ali_Al_Khalifa
# Processing article 619/7155: Abdulrahman_al-Nuaimi
# Processing article 620/7155: Ammar_Qambar
# Processing article 621/7155: Isa_Qassim
# Processing article 622/7155: Abdulla_Hassan_Saif
# Processing article 623/7155: Ali_bin_Saleh_Al_Saleh
# Processing article 624/7155: Ahmed_Al-Salloum
# Processing article 625/7155: Salman_bin_Hamad_Al_Khalifa
# Processing article 626/7155: Abdul_Motaleb
# Processing article 627/7155: Abdus_Salam_(Chattogram_politician)
# Processing article 628/7155: Abul_Hashim
# Processing article 629/7155: Oli_Ahad
# Processing article 630/7155: Chowdhury_Shamsuddin_Ahmed
# Processing article 631/7155: Farid_Ahmed
# Processing article 632/7155: Muzaffar_Ahmed_(NAP_politician)
# Processing article 633/7155: AKM_Hafizuddin
# Processing article 634/7155: Mohammad_Manjur_Alam
# Processing article 635/7155: M_Hossain_Ali
# Processing article 636/7155: Aminul_Islam_Rabel
# Processing article 637/7155: Mohammad_A._Arafat
# Processing article 638/7155: Ashab_Uddin_Ahmad
# Processing article 639/7155: Shafiqur_Rahman_Badsha
# Processing article 640/7155: Selina_Banu
# Processing article 641/7155: Nurul_Huq_Bhuiyan
# Processing article 642/7155: Birendra_Kishore_Roaza
# Processing article 643/7155: Bishnu_Chattopadhyay
# Processing article 644/7155: AKM_Fazlul_Kabir_Chowdhury
# Processing article 645/7155: Aminul_Islam_Chowdhury
# Processing article 646/7155: Anwarul_Karim_Chowdhury
# Processing article 647/7155: Moinuddin_Ahmed_Chowdhury
# Processing article 648/7155: Sarwar_Jan_Chowdhury
# Processing article 649/7155: Shahinur_Pasha_Chowdhury
# Processing article 650/7155: Yusuf_Ali_Chowdhury
# Processing article 651/7155: Haji_Mohammad_Danesh
# Processing article 652/7155: Pulin_De
# Processing article 653/7155: James_Leo_Ferguson
# Processing article 654/7155: Abdul_Halim_Ghaznavi
# Processing article 655/7155: Debendra_Nath_Ghosh
# Processing article 656/7155: Ranesh_Das_Gupta
# Processing article 657/7155: AKM_Fazlul_Haque_(Jatiya_Party_politician)
# Processing article 658/7155: Syed_Najmuddin_Hashim
# Processing article 659/7155: M._Anwar_Hossain
# Processing article 660/7155: Nozir_Hossain
# Processing article 661/7155: Husam_Uddin_Chowdhury_Fultali
# Processing article 662/7155: Syed_Muhammad_Ibrahim
# Processing article 663/7155: Abul_Kashem
# Processing article 664/7155: Abul_Kashem_Khan
# Processing article 665/7155: Hatem_Ali_Khan
# Processing article 666/7155: Muhammad_Hamidullah_Khan
# Processing article 667/7155: Yar_Mohammad_Khan
# Processing article 668/7155: Kazi_Abdus_Shahid_Lal
# Processing article 669/7155: Jyotirindra_Bodhipriya_Larma
# Processing article 670/7155: Shamima_Harun_Lubna
# Processing article 671/7155: Manik_Lal_Ray
# Processing article 672/7155: Manjurul_Imam
# Processing article 673/7155: Mushrefa_Mishu
# Processing article 674/7155: Moin_Uddin_(politician)
# Processing article 675/7155: Fazlul_Haque_Montu
# Processing article 676/7155: Mujahidul_Islam_Selim
# Processing article 677/7155: Mujibur_Rahman_(Chattogram_politician)
# Processing article 678/7155: Shafiul_Alam_Chowdhury_Nadel
# Processing article 679/7155: SM_Nuruzzaman
# Processing article 680/7155: Shamsul_Huda_Panchbagi
# Processing article 681/7155: Muhammad_Bayazeed_Khan_Panni
# Processing article 682/7155: Ferdous_Ahmed_Qureshi
# Processing article 683/7155: Asheq_Ullah_Rafiq
# Processing article 684/7155: Abdur_Rahim_(scholar)
# Processing article 685/7155: Habibar_Rahman
# Processing article 686/7155: M._M._Rahmatullah
# Processing article 687/7155: Golam_Maula_Rony
# Processing article 688/7155: Devasish_Roy
# Processing article 689/7155: Mahmudul_Haque_Sayem
# Processing article 690/7155: Maulana_Shakhawat
# Processing article 691/7155: Abul_Kalam_Shamsuddin
# Processing article 692/7155: Badruddoza_Ahmed_Shuja
# Processing article 693/7155: Sourendra_Nath_Chakraborty
# Processing article 694/7155: Mohammad_Sultan
# Processing article 695/7155: Syed_Sayedul_Haque_Suman
# Processing article 696/7155: Mohammad_Toaha
# Processing article 697/7155: Badruddin_Umar
# Processing article 698/7155: Zahidunnabi_Dewan_Shamim
# Processing article 699/7155: Mohammad_Zillur_Rahman
# Processing article 700/7155: Elliott_Belgrave
# Processing article 701/7155: Chad_Blackman
# Processing article 702/7155: Santia_Bradshaw
# Processing article 703/7155: Sonia_Browne
# Processing article 704/7155: Michael_A._Carrington
# Processing article 705/7155: William_Fondleroy_Duguid
# Processing article 706/7155: Reginald_Farley
# Processing article 707/7155: Adrian_Forde
# Processing article 708/7155: Cynthia_Y._Forde
# Processing article 709/7155: Ian_Gooding-Edghill
# Processing article 710/7155: Damien_K._A._Griffith
# Processing article 711/7155: Crystal_Haynes
# Processing article 712/7155: Philip_St._Hill
# Processing article 713/7155: Kirk_Matthew_Humphrey
# Processing article 714/7155: Davidson_Ishmael
# Processing article 715/7155: Colin_Everett_Jordan
# Processing article 716/7155: John_Andrew_King
# Processing article 717/7155: Shantal_Munro-Knight
# Processing article 718/7155: Glyne_Murray
# Processing article 719/7155: Charles_Duncan_O'Neal
# Processing article 720/7155: Samuel_Jackman_Prescod
# Processing article 721/7155: Shanika_Roberts-Odle
# Processing article 722/7155: Ryan_Straughn
# Processing article 723/7155: Dwight_Sutherland
# Processing article 724/7155: Kerrie_Symmonds
# Processing article 725/7155: Yury_Ambrazevich
# Processing article 726/7155: Aliaksandr_Azarau
# Processing article 727/7155: Lyavon_Barshchewski
# Processing article 728/7155: Siarhei_Cherachen
# Processing article 729/7155: Zmitser_Dashkevich
# Processing article 730/7155: Siamion_Domash
# Processing article 731/7155: Tsimafei_Dranchuk
# Processing article 732/7155: Alaksandar_Dubko
# Processing article 733/7155: Gennady_Grushevoy
# Processing article 734/7155: Moshe_Gutman
# Processing article 735/7155: Uładzimir_Hančaryk
# Processing article 736/7155: Tamaš_Hryb
# Processing article 737/7155: Anatoĺ_Kalinin
# Processing article 738/7155: Voĺha_Karač
# Processing article 739/7155: Uładzisłau_Kazłouski
# Processing article 740/7155: Tadeusz_Kościuszko
# Processing article 741/7155: Ivan_Kubrakov
# Processing article 742/7155: Vladimir_Kumets
# Processing article 743/7155: Valery_Levaneuski
# Processing article 744/7155: Uladzimir_Mackievič
# Processing article 745/7155: V._L._Mukha
# Processing article 746/7155: Jan_Pazniak
# Processing article 747/7155: Aleksandr_Potupa
# Processing article 748/7155: Pyotr_Prakapovich
# Processing article 749/7155: Alexander_Radkov
# Processing article 750/7155: Symon_Rak-Michajłoŭski
# Processing article 751/7155: Vladimir_Rusakevich
# Processing article 752/7155: Ihar_Rynkevich
# Processing article 753/7155: Valery_Sakhashchyk
# Processing article 754/7155: Dominik_Semashko
# Processing article 755/7155: Aliaksandr_Shakutsin
# Processing article 756/7155: Nikolai_Shelyagovich
# Processing article 757/7155: Jan_Stankievič
# Processing article 758/7155: Mikola_Statkevich
# Processing article 759/7155: Sergei_Tikhanovsky
# Processing article 760/7155: Aleksandr_Turchin
# Processing article 761/7155: Yury_Voskresensky
# Processing article 762/7155: Edward_Woyniłłowicz
# Processing article 763/7155: Ivan_Yermachenka
# Processing article 764/7155: Manuel_Abramowicz
# Processing article 765/7155: Rudy_Aernoudt
# Processing article 766/7155: Herman_Baltia
# Processing article 767/7155: Jan_Béghin
# Processing article 768/7155: Frank_Beke
# Processing article 769/7155: Gustave_Boël
# Processing article 770/7155: Pol_Clovis_Boël
# Processing article 771/7155: Antoine_Brun
# Processing article 772/7155: Fernand_Cocq
# Processing article 773/7155: Émile_Coulonvaux
# Processing article 774/7155: Auguste_Couvreur
# Processing article 775/7155: Nico_Cué
# Processing article 776/7155: Pierre_David_(mayor)
# Processing article 777/7155: Marcel_de_Baer
# Processing article 778/7155: August_De_Boodt
# Processing article 779/7155: Norbert_De_Cuyper
# Processing article 780/7155: Dirk_De_fauw
# Processing article 781/7155: René_De_Feyter
# Processing article 782/7155: François-Philippe_de_Haussy
# Processing article 783/7155: Victor_de_Laveleye
# Processing article 784/7155: Édouard_Descamps
# Processing article 785/7155: José_Desmarets
# Processing article 786/7155: Émile_van_Dievoet
# Processing article 787/7155: Marc_Drumaux
# Processing article 788/7155: Jos_Dupré
# Processing article 789/7155: Françoise_Dupuis
# Processing article 790/7155: Veerle_Geerinckx
# Processing article 791/7155: Eugène_Goblet_d'Alviella
# Processing article 792/7155: Julien_Goekint
# Processing article 793/7155: Jean-Pierre_Grafé
# Could not retrieve score for Jean-Pierre_Grafé
# Processing article 794/7155: Jacques_Grippa
# Processing article 795/7155: Guy_Hance
# Processing article 796/7155: Joris_Helleputte
# Processing article 797/7155: Lucienne_Herman-Michielsens
# Processing article 798/7155: Jules_Hiernaux
# Processing article 799/7155: Julius_Hoste_Jr.
# Processing article 800/7155: Norbert_Hougardy
# Processing article 801/7155: Joseph_Houssa
# Processing article 802/7155: Vincent_Houssiau
# Processing article 803/7155: Pierre_Van_Humbeeck
# Processing article 804/7155: Dorah_Ilunga
# Processing article 805/7155: Pierre_Imperiali
# Processing article 806/7155: Jean-François_Istasse
# Processing article 807/7155: Milou_Jeunehomme
# Processing article 808/7155: Georges_Kaeckenbeeck
# Processing article 809/7155: André_Kempinaire
# Processing article 810/7155: Ahmet_Koç_(politician)
# Processing article 811/7155: Willy_Kuijpers
# Processing article 812/7155: Rachid_Madrane
# Processing article 813/7155: Luc_Michel
# Processing article 814/7155: Fientje_Moerman
# Processing article 815/7155: André_Molitor
# Processing article 816/7155: Jean_Pede
# Processing article 817/7155: Pierre_Emmanuel_Félix_Chazal
# Processing article 818/7155: Jean-Marie_Piret
# Processing article 819/7155: André-Eugène_Pirson
# Processing article 820/7155: Marjet_Van_Puymbroeck
# Processing article 821/7155: Jean_Richardot_the_Younger
# Processing article 822/7155: Gustave_Rolin-Jaequemyns
# Processing article 823/7155: Hippolyte_Rolin
# Processing article 824/7155: Father_Samuel
# Processing article 825/7155: Louis-Joseph_Seutin
# Processing article 826/7155: Alfons_Siffer
# Processing article 827/7155: Cyrille_Tahay
# Processing article 828/7155: Jacques_Timmermans
# Processing article 829/7155: Robert_Urbain
# Processing article 830/7155: Adolphe_Van_Glabbeke
# Processing article 831/7155: Gaëtan_Van_Goidsenhoven
# Processing article 832/7155: Jacques_Van_Gompel
# Processing article 833/7155: Marcel_Van_Langenhove_(referee)
# Processing article 834/7155: Johan_Verbeke
# Processing article 835/7155: Yvan_Verougstraete
# Processing article 836/7155: Lodewijk_Verreycken
# Processing article 837/7155: Louis_Waltniel
# Processing article 838/7155: Yves_de_Wasseige
# Processing article 839/7155: Roger_Windels
# Processing article 840/7155: Jacques_van_Ypersele_de_Strihou
# Processing article 841/7155: Nemencio_Acosta
# Processing article 842/7155: Basilio_Ah
# Processing article 843/7155: Beverly_Castillo
# Processing article 844/7155: Charles_Bartlett_Hyde
# Processing article 845/7155: Glenn_Godfrey
# Processing article 846/7155: Alexander_Albert_Hunter
# Processing article 847/7155: Elfreda_Reyes
# Processing article 848/7155: Bert_Tucker
# Processing article 849/7155: Woldrich_Harrison_Courtenay
# Processing article 850/7155: Arnauld_Antoine_Akodjènou
# Processing article 851/7155: Jules-Armand_Aniambossou
# Processing article 852/7155: Francis_Covi
# Processing article 853/7155: Sefou_Fagbohoun
# Processing article 854/7155: Louis_Hunkanrin
# Processing article 855/7155: Louis_Ignacio-Pinto
# Processing article 856/7155: Arouna_Mama
# Processing article 857/7155: D._N._Dhungyel
# Processing article 858/7155: Dorjee_Wangmo
# Processing article 859/7155: Ugyen_Dorji_(DNT_politician)
# Processing article 860/7155: Zangley_Dukpa
# Processing article 861/7155: Dupthob
# Processing article 862/7155: Choki_Gyeltshen
# Processing article 863/7155: Sherub_Gyeltshen
# Processing article 864/7155: Choida_Jamtsho
# Processing article 865/7155: Rinzin_Jamtsho
# Processing article 866/7155: Shingkhar_Lam
# Processing article 867/7155: Tshewang_Lhamo
# Processing article 868/7155: Kuenga_Loday
# Processing article 869/7155: Dorji_Namgyal
# Processing article 870/7155: Jigme_Namgyal_(Bhutan)
# Processing article 871/7155: Kunzang_C._Namgyel
# Processing article 872/7155: Wangdi_Norbu
# Processing article 873/7155: Pema_Chewang
# Processing article 874/7155: Pema_Gyamtsho
# Processing article 875/7155: Kinga_Penjor
# Processing article 876/7155: Yeshey_Penjor
# Processing article 877/7155: Thakur_S._Powdyel
# Processing article 878/7155: Jai_Bir_Rai
# Processing article 879/7155: Karma_Rangdol
# Processing article 880/7155: Chogyal_Dago_Rigdzin
# Processing article 881/7155: Loknath_Sharma
# Processing article 882/7155: Tenzin_(politician)
# Processing article 883/7155: Sonam_Tobgye
# Processing article 884/7155: Dorji_Tshering
# Processing article 885/7155: Kinga_Tshering
# Processing article 886/7155: Namgay_Tshering
# Processing article 887/7155: Ugyen_Tshering
# Processing article 888/7155: Jigme_Wangchuk
# Processing article 889/7155: Lhatu_Wangchuk
# Processing article 890/7155: Khandu_Wangchuk
# Processing article 891/7155: Norbu_Wangchuk
# Processing article 892/7155: Tshering_Wangchuk
# Processing article 893/7155: Karma_Donnen_Wangdi
# Processing article 894/7155: Tshencho_Wangdi
# Processing article 895/7155: Ugyen_Wangdi
# Processing article 896/7155: Dechen_Wangmo_(politician)
# Processing article 897/7155: Dechen_Zangmo
# Processing article 898/7155: Neten_Zangmo
# Processing article 899/7155: Nidup_Zangpo
# Processing article 900/7155: Yeshey_Zimba
# Processing article 901/7155: Botche_Candé
# Processing article 902/7155: Juliano_Fernandes
# Processing article 903/7155: Teodora_Inácia_Gomes
# Processing article 904/7155: Desejado_Lima_da_Costa
# Processing article 905/7155: Aristide_Menezes
# Processing article 906/7155: Florentino_Mendes_Pereira
# Processing article 907/7155: Carmelita_Pires
# Processing article 908/7155: Agnelo_Regalla
# Processing article 909/7155: Nataniel_Aguirre
# Processing article 910/7155: Francisco_Argandoña
# Processing article 911/7155: Atanasio_de_Urioste_Velasco
# Processing article 912/7155: Isaac_Ávalos
# Processing article 913/7155: Augusto_Céspedes
# Processing article 914/7155: Adolfo_Chávez
# Processing article 915/7155: Chi_Hyun_Chung
# Processing article 916/7155: Pantaleón_Dalence
# Processing article 917/7155: Rafael_Peña
# Processing article 918/7155: Marcelo_Elío
# Processing article 919/7155: Marcial_Fabricano
# Processing article 920/7155: Fernando_Eloy_Guachalla
# Processing article 921/7155: Toribia_Lero_Quispe
# Processing article 922/7155: Antonio_Machaca
# Processing article 923/7155: Adolfo_Mendoza
# Processing article 924/7155: Manuel_de_Molina_Zamudio
# Processing article 925/7155: Pedro_Domingo_Murillo
# Processing article 926/7155: Francisco_Burdett_O'Connor
# Processing article 927/7155: Manuel_Luis_de_Oliden
# Processing article 928/7155: Simón_Iturri_Patiño
# Processing article 929/7155: Bonifacio_Pinedo
# Processing article 930/7155: Julio_Pinedo
# Processing article 931/7155: Gary_Prado_Salmón
# Processing article 932/7155: José_Mariano_Serrano
# Processing article 933/7155: Moisés_Torres_(politician)
# Processing article 934/7155: Fernando_Vargas_Mosua
# Processing article 935/7155: Jaime_de_Zudáñez
# Processing article 936/7155: Kemal_Ademović
# Processing article 937/7155: Mehmed_Alajbegović
# Processing article 938/7155: Boško_Baškot
# Processing article 939/7155: Salko_Bukvarević
# Processing article 940/7155: Sabina_Ćudić
# Processing article 941/7155: Dženan_Đonlagić
# Processing article 942/7155: Edin_Forto
# Processing article 943/7155: Dževad_Galijašević
# Processing article 944/7155: Josip_Grubeša
# Processing article 945/7155: Ankica_Gudeljević
# Processing article 946/7155: Hakija_Hadžić
# Processing article 947/7155: Mirsad_Hadžikadić
# Processing article 948/7155: Sanjin_Halimović
# Processing article 949/7155: Sevlid_Hurtić
# Processing article 950/7155: Husein_Miljković
# Processing article 951/7155: Jasmin_Imamović
# Processing article 952/7155: Adamir_Jerković
# Processing article 953/7155: Esed_Kadrić
# Processing article 954/7155: Mehmed_Kapetanović
# Processing article 955/7155: Osman_Karabegović
# Processing article 956/7155: Rusmir_Mahmutćehajić
# Processing article 957/7155: Amor_Mašović
# Processing article 958/7155: Božidar_Matić
# Processing article 959/7155: Dragan_Mektić
# Processing article 960/7155: Ademaga_Mešić
# Processing article 961/7155: Jelka_Miličević
# Processing article 962/7155: Abdulah_Mutapčić
# Processing article 963/7155: Abdulah_Nakaš
# Processing article 964/7155: Damir_Nikšić
# Processing article 965/7155: Ismet_Popovac
# Processing article 966/7155: Hakija_Pozderac
# Processing article 967/7155: Hamdija_Pozderac
# Processing article 968/7155: Nurija_Pozderac
# Processing article 969/7155: Đuro_Pucar
# Processing article 970/7155: Svetozar_Pudarić
# Processing article 971/7155: Alen_Šeranić
# Processing article 972/7155: Uglješa_Uzelac
# Processing article 973/7155: Nezir_Škaljić
# Processing article 974/7155: Ibrahim_Spahić
# Processing article 975/7155: Jelena_Trivić
# Processing article 976/7155: Milan_Uzelac
# Processing article 977/7155: Dragan_Vikić
# Processing article 978/7155: Miloš_Vukašinović
# Processing article 979/7155: Philip_Matante
# Processing article 980/7155: Leetile_Disang_Raditladi
# Processing article 981/7155: Patrick_van_Rensburg
# Processing article 982/7155: Tobias_de_Aguiar
# Processing article 983/7155: Medeiros_e_Albuquerque
# Processing article 984/7155: Léo_de_Almeida_Neves
# Processing article 985/7155: Antônio_Pinto_Chichorro_da_Gama
# Processing article 986/7155: Cipriano_Barata
# Processing article 987/7155: Jader_Barbalho_Filho
# Processing article 988/7155: Irani_Barbosa
# Processing article 989/7155: Djalma_Bastos_de_Morais
# Processing article 990/7155: Henrique_de_Beaurepaire-Rohan,_Viscount_of_Beaurepaire-Rohan
# Processing article 991/7155: Natália_Bastos_Bonavides
# Processing article 992/7155: Marcos_Braz
# Processing article 993/7155: Amador_Bueno
# Processing article 994/7155: Maurício_Campos_de_Medeiros
# Processing article 995/7155: Marcelo_Cecé
# Processing article 996/7155: Izolda_Cela
# Processing article 997/7155: Margarete_Coelho
# Processing article 998/7155: Paulo_Corrêa
# Processing article 999/7155: Miguel_Couto
# Processing article 1000/7155: João_Cunha_(politician)
# Processing article 1001/7155: Manuel_Jacinto_Nogueira_da_Gama,_Marquis_of_Baependi
# Processing article 1002/7155: Aécio_de_Borba
# Processing article 1003/7155: José_Abílio_Silva_de_Santana
# Processing article 1004/7155: Alércio_Dias
# Processing article 1005/7155: Délio_dos_Santos
# Processing article 1006/7155: Ademar_Frederico_Duwe
# Processing article 1007/7155: Paulo_Cesar_Farias
# Processing article 1008/7155: Emília_Fernandes
# Processing article 1009/7155: José_Carlos_da_Silva_Mayrink_Ferrão
# Processing article 1010/7155: Juscelino_Filho
# Processing article 1011/7155: Pedro_Paulino_de_Fonseca
# ...
# Processing article 6820/7155: Olha_Bench
# Processing article 6821/7155: Serhiy_Berezenko
# Processing article 6822/7155: Andriy_Beshta
# Processing article 6823/7155: Ivan_Bisyuk
# Processing article 6824/7155: Volodymyr_Boyko
# Processing article 6825/7155: Ihor_Dolhov
# Processing article 6826/7155: Anatoliy_Fedorchuk
# Processing article 6827/7155: Ivan_Gel
# Processing article 6828/7155: Moshe_Gutman
# Processing article 6829/7155: Olena_Halushka
# Processing article 6830/7155: Izet_Hdanov
# Processing article 6831/7155: Artur_Herasymov
# Processing article 6832/7155: Valeriy_Holovko
# Processing article 6833/7155: Volodymyr_Hryshchenko
# Processing article 6834/7155: Stepan_Ivakhiv
# Processing article 6835/7155: Borys_Kachura
# Processing article 6836/7155: Dmytro_Kashchuk
# Processing article 6837/7155: Serhii_Khlan
# Processing article 6838/7155: Borys_Klimchuk_(politician)
# Processing article 6839/7155: Klitschko_brothers
# Processing article 6840/7155: Mykola_Kolisnyk
# Processing article 6841/7155: Mykhailo_Korolenko
# Processing article 6842/7155: Ivan_Korshynskyi
# Processing article 6843/7155: Roman_Kostenko
# Processing article 6844/7155: Heorhiy_Kryuchkov
# Processing article 6845/7155: Mykola_Kulinich
# Processing article 6846/7155: Vitalii_Kurylo
# Processing article 6847/7155: Anatolii_Kutsevol
# Processing article 6848/7155: Ihor_Kyzym
# Processing article 6849/7155: Hennadiy_Lahuta
# Processing article 6850/7155: Yurii_Lavreniuk
# Processing article 6851/7155: Andriy_Levus
# Processing article 6852/7155: Ivan_Lypa
# Processing article 6853/7155: Roman_Mashovets
# Processing article 6854/7155: Denys_Maslov
# Processing article 6855/7155: Volodymyr_Matvienko
# Processing article 6856/7155: Pavlo_Matvienko
# Processing article 6857/7155: Oleh_Meidych
# Processing article 6858/7155: Mykola_Popov
# Processing article 6859/7155: Denys_Myrgorodskyi
# Processing article 6860/7155: Sergey_Nazarov
# Processing article 6861/7155: Andriy_Odarchenko
# Processing article 6862/7155: Hryhoriy_Omelchenko
# Processing article 6863/7155: Volodymyr_Petrov
# Processing article 6864/7155: Mykola_Petruk
# Processing article 6865/7155: Vasyl_Poraiko
# Processing article 6866/7155: Yelena_Protsenko
# Processing article 6867/7155: Mykhailo_Reznik
# Processing article 6868/7155: Oleksandr_Ryzhenkov
# Processing article 6869/7155: Petro_Gadz
# Processing article 6870/7155: Ruslan_Magomedov_(economist)
# Processing article 6871/7155: Oleksandr_Ruzhytskyi
# Processing article 6872/7155: Mykola_Riabovil
# Processing article 6873/7155: Vladimir_Saldo
# Processing article 6874/7155: Olena_Semeniaka
# Processing article 6875/7155: Volodymyr_Serhiychuk
# Processing article 6876/7155: Oleh_Shamshur
# Processing article 6877/7155: Vyacheslav_Shapovalov
# Processing article 6878/7155: Serhii_Shapran
# Processing article 6879/7155: Iryna_Stavchuk
# Processing article 6880/7155: Volodymyr_Stelmakh
# Processing article 6881/7155: Viacheslav_Suprunenko
# Processing article 6882/7155: Taras_Tarasenko
# Processing article 6883/7155: Volodymyr_Tsvil
# Processing article 6884/7155: Volodymyr_Tyahlo
# Processing article 6885/7155: Serhiy_Tymchenko
# Processing article 6886/7155: Kyrylo_Tymoshenko
# Processing article 6887/7155: Evgeniy_Udod
# Processing article 6888/7155: Dmytro_Vorona
# Processing article 6889/7155: Mykola_Yankovsky
# Processing article 6890/7155: Kostiantyn_Yastrub
# Processing article 6891/7155: Yuriy_Vozniuk
# Processing article 6892/7155: Andriy_Yusov
# Processing article 6893/7155: Anatoliy_Zasukha
# Processing article 6894/7155: Vitaly_Zholobov
# Processing article 6895/7155: Luis_Almagro
# Processing article 6896/7155: Sebastián_Bauzá
# Processing article 6897/7155: Mónica_Bottero
# Processing article 6898/7155: Jorge_Bruni
# Processing article 6899/7155: Guillermo_Chifflet
# Processing article 6900/7155: Laura_Cortinas
# Processing article 6901/7155: Guillermo_Domenech
# Processing article 6902/7155: Lorenzo_Antonio_Fernández
# Processing article 6903/7155: Pedro_Figari
# Processing article 6904/7155: Liliam_Kechichián
# Processing article 6905/7155: Dámaso_Antonio_Larrañaga
# Processing article 6906/7155: Juan_Francisco_Larrobla
# Processing article 6907/7155: Eduardo_Lorier
# Processing article 6908/7155: Hector_Luisi
# Processing article 6909/7155: Guido_Manini_Ríos
# Processing article 6910/7155: Isidoro_de_María
# Processing article 6911/7155: Luis_Melián_Lafinur
# Processing article 6912/7155: Antonio_Mercader
# Processing article 6913/7155: Pablo_Mieres
# Processing article 6914/7155: José_Benito_Monterroso
# Processing article 6915/7155: Tristán_Narvaja
# Processing article 6916/7155: Gonzalo_Nin_Novoa
# Processing article 6917/7155: Edgardo_Novick
# Processing article 6918/7155: María_Inés_Obaldía
# Processing article 6919/7155: Yamandú_Orsi
# Processing article 6920/7155: José_Brito_del_Pino
# Processing article 6921/7155: Enrique_Pintado
# Processing article 6922/7155: Carlos_Pita_(politician)
# Processing article 6923/7155: Carlos_Quijano
# Processing article 6924/7155: Laura_Raffo
# Processing article 6925/7155: José_Rondeau
# Processing article 6926/7155: Florencio_Sánchez
# Processing article 6927/7155: José_Pedro_Varela
# Processing article 6928/7155: Pedro_Vaz_(diplomat)
# Processing article 6929/7155: Mateo_Vidal
# Processing article 6930/7155: Jorge_Zabalza
# Processing article 6931/7155: Ikhtiyor_Abdullayev
# Processing article 6932/7155: Adham_Ahmedbaev
# Processing article 6933/7155: Jakhongir_Artikkhodjayev
# Processing article 6934/7155: Valery_Ataev
# Processing article 6935/7155: Abdusalom_Azizov
# Processing article 6936/7155: Uktam_Barnoev
# Processing article 6937/7155: Sa'dulla_Begaliyev
# Processing article 6938/7155: Torokul_Dzhanuzakov
# Processing article 6939/7155: Rustam_Inoyatov
# Processing article 6940/7155: Rashid_Kadyrov
# Processing article 6941/7155: Karim_Kamalov
# Processing article 6942/7155: Tatyana_Karimova
# Processing article 6943/7155: Erkin_Khalilov
# Processing article 6944/7155: Sherzodkhon_Kudratkhuja
# Processing article 6945/7155: Bakhodir_Kurbanov_(general)
# Processing article 6946/7155: Jahangir_Mamatov
# Processing article 6947/7155: Rimajon_Xudoyberganova
# Processing article 6948/7155: Boʻritosh_Mustafoyev
# Processing article 6949/7155: Bahrom_Norqobilov
# Processing article 6950/7155: Narzullo_Oblomurodov
# Processing article 6951/7155: Ravshanbek_Qurbonov
# Processing article 6952/7155: Baxtiyor_Rahimov
# Processing article 6953/7155: Bekjon_Rakhmonov
# Processing article 6954/7155: Bakhodir_Khan_Turkistan
# Processing article 6955/7155: Qobul_Tursunov
# Processing article 6956/7155: Vincent_Lunabek
# Processing article 6957/7155: President_of_Vanuatu
# Processing article 6958/7155: Jimmy_Stevens_(politician)
# Processing article 6959/7155: Dinh_Van_Than
# Processing article 6960/7155: Fernando_Adames_Torres
# Processing article 6961/7155: Ivonne_Attas
# Processing article 6962/7155: Fidel_Barbarito
# Processing article 6963/7155: Pedro_Bastidas
# Processing article 6964/7155: Alejandra_Benítez
# Processing article 6965/7155: José_Brito_(politician)
# Processing article 6966/7155: Buenaventura_Macabeo_Maldonado_Vivas
# Processing article 6967/7155: Rubén_González_Cárdenas
# Processing article 6968/7155: José_Curiel
# Processing article 6969/7155: Felix_Díaz_Ortega
# Processing article 6970/7155: Vicente_José_Gregorio_Díaz_Silva
# Processing article 6971/7155: Alí_Domínguez
# Processing article 6972/7155: Franklyn_Duarte
# Processing article 6973/7155: Alberto_Franceschi
# Processing article 6974/7155: Arnoldo_Gabaldón
# Processing article 6975/7155: Vladimir_Gessen_(Venezuelan_politician)
# Processing article 6976/7155: Jorge_Giordani
# Processing article 6977/7155: César_González_Martínez
# Processing article 6978/7155: Luis_Graterol_Caraballo
# Processing article 6979/7155: Liborio_Guarulla
# Processing article 6980/7155: José_Bernabé_Gutiérrez
# Processing article 6981/7155: María_Cristina_Iglesias
# Processing article 6982/7155: Reinaldo_Iturriza
# Processing article 6983/7155: Andrés_Izarra
# Processing article 6984/7155: Reinaldo_Leandro_Mora
# Processing article 6985/7155: Carlos_Augusto_León
# Processing article 6986/7155: Ramón_Lobo_(economist)
# Processing article 6987/7155: Jorge_Elieser_Márquez
# Processing article 6988/7155: Américo_Martín
# Processing article 6989/7155: Nelson_Martínez_(politician)
# Processing article 6990/7155: Francisco_de_Miranda
# Processing article 6991/7155: Reinaldo_Muñoz_Pedroza
# Processing article 6992/7155: Dia_Nader_de_El-Andari
# Processing article 6993/7155: Moisés_Naím
# Processing article 6994/7155: Freddy_Ñáñez
# Processing article 6995/7155: Pablo_Acosta_Ortiz
# Processing article 6996/7155: Renny_Ottolina
# Processing article 6997/7155: Alejandro_Peña_Esclusa
# Processing article 6998/7155: Miguel_Peña_(politician)
# Processing article 6999/7155: Lewis_Pérez
# Processing article 7000/7155: Arkiely_Perfecto
# Processing article 7001/7155: Eduardo_Piñate
# Processing article 7002/7155: Humberto_Prado
# Processing article 7003/7155: Omar_Prieto
# Processing article 7004/7155: Benjamín_Rausseo
# Processing article 7005/7155: Manuel_Felipe_Rugeles
# Processing article 7006/7155: Carlos_Santana_Tovar
# Processing article 7007/7155: Milena_Sardi_de_Selle
# Processing article 7008/7155: Carlos_Eduardo_Stolk
# Processing article 7009/7155: Bolivia_Suárez
# Processing article 7010/7155: Gustavo_Tarre
# Processing article 7011/7155: José_Herrera_Uslar
# Processing article 7012/7155: Addy_Valero
# Processing article 7013/7155: José_Antonio_Velutini
# Processing article 7014/7155: Henry_Ventura
# Processing article 7015/7155: Nervis_Villalobos
# Processing article 7016/7155: Bùi_Tiến_Dũng_(politician)
# Processing article 7017/7155: Chu_Văn_An
# Processing article 7018/7155: Nguyễn_Quốc_Định
# Processing article 7019/7155: Đinh_Xuân_Quảng
# Processing article 7020/7155: Kiem_Do
# Processing article 7021/7155: Đỗ_Quang_Giai
# Processing article 7022/7155: Hồ_Đắc_Điềm
# Processing article 7023/7155: Hồ_Văn_Nhựt
# Processing article 7024/7155: Hoàng_Cao_Khải
# Processing article 7025/7155: Hoang_Van_Chi
# Processing article 7026/7155: Huỳnh_Văn_Cao
# Processing article 7027/7155: Kiều_Mộng_Thu
# Processing article 7028/7155: Lê_Minh_Hương
# Processing article 7029/7155: Lê_Quốc_Minh
# Processing article 7030/7155: Lê_Văn_Thành
# Processing article 7031/7155: Lương_Thế_Huy
# Processing article 7032/7155: Nguyễn_Hồng_Diên
# Processing article 7033/7155: Nguyễn_Đức_Chung
# Processing article 7034/7155: Nguyễn_Dương_Đôn
# Processing article 7035/7155: Nguyễn_Duy_Quý
# Processing article 7036/7155: Nguyễn_Hợp_Đoàn
# Processing article 7037/7155: Nguyễn_Phan_Long
# Processing article 7038/7155: Nguyễn_Quốc_Cường
# Processing article 7039/7155: Nguyễn_Thị_Hồng_(economist)
# Processing article 7040/7155: Nguyễn_Thị_Thập
# Processing article 7041/7155: Nguyễn_Văn_Huyền
# Processing article 7042/7155: Nguyễn_Văn_Lực
# Processing article 7043/7155: Nguyễn_Văn_Trân
# Processing article 7044/7155: Nguyễn_Văn_Xuân
# Processing article 7045/7155: Phan_Anh
# Processing article 7046/7155: Tạ_Quang_Bửu
# Processing article 7047/7155: Tran_Minh_Tiet
# Processing article 7048/7155: Trần_Quốc_Vượng_(politician)
# Processing article 7049/7155: Trần_Văn_Hữu
# Processing article 7050/7155: Trương_Đình_Dzu
# Processing article 7051/7155: Võ_Văn_Thưởng
# Processing article 7052/7155: Abdullah_Noman
# Processing article 7053/7155: Hashid_Abdullah_al-Ahmar
# Processing article 7054/7155: Himyar_Abdullah_al-Ahmar
# Processing article 7055/7155: Sam_Yahya_Al-Ahmar
# Processing article 7056/7155: Ameen_Ali_al-Akimi
# Processing article 7057/7155: Talal_Aklan
# Processing article 7058/7155: Abdullatif_Al-Sayed
# Processing article 7059/7155: Muhammad_Musa_al-Amri
# Processing article 7060/7155: Mohamed_al-Atifi
# Processing article 7061/7155: Yasser_Al-Awadi
# Processing article 7062/7155: Sagheer_Hamoud_Aziz
# Processing article 7063/7155: Sultan_al-Barakani
# Processing article 7064/7155: Faraj_Salmin_Al-Bahsani
# Processing article 7065/7155: Ali_Al_Bukhaiti
# Processing article 7066/7155: Bruce_Conde
# Processing article 7067/7155: Abdul_Wahab_Al-Dailami
# Processing article 7068/7155: Ali_Ahmad_Nasser_al-Dhahab
# Processing article 7069/7155: Badreddin_al-Houthi
# Processing article 7070/7155: Ibrahim_Bin_Ali_Al_Wazeer
# Processing article 7071/7155: Mohammed_Lutf_al-Iryani
# Processing article 7072/7155: Abd_Al-Rahman_Ali_Al-Jifri
# Processing article 7073/7155: Hussein_Khairan
# Processing article 7074/7155: Mohammed_Ali_Al-Maqdashi
# Processing article 7075/7155: Hooria_Mashhour
# Processing article 7076/7155: Muhammad_bin_Yahya_bin_Muhammad
# Processing article 7077/7155: Abdul_Qader_Qahtan
# Processing article 7078/7155: Abdulwahab_al-Rawhani
# Processing article 7079/7155: Mohammed_al-Sabry
# Processing article 7080/7155: Yahya_Mohamed_Abdullah_Saleh
# Processing article 7081/7155: Ali_Taysir
# Processing article 7082/7155: Yahya_Muhammad_Hamid_ed-Din
# Processing article 7083/7155: Aidarus_al-Zoubaidi
# Processing article 7084/7155: Francis_Kapyanga
# Processing article 7085/7155: Lily_Monze
# Processing article 7086/7155: Olipa_Phiri
# Processing article 7087/7155: Gift_Banda
# Processing article 7088/7155: Flora_Buka
# Processing article 7089/7155: Bulelani_Lobengula
# Processing article 7090/7155: Joseph_Makamba_Busha
# Processing article 7091/7155: Darlington_Dzikamai_Chigumbu
# Processing article 7092/7155: James_Chikerema
# Processing article 7093/7155: Paul_Chimedza
# Processing article 7094/7155: Chenhamo_Chimutengwende
# Processing article 7095/7155: Ruth_Chinamano
# Processing article 7096/7155: George_Chiweshe
# Processing article 7097/7155: Phillip_Chiyangwa
# Processing article 7098/7155: Guy_Clutton-Brock
# Processing article 7099/7155: Margaret_Dongo
# Processing article 7100/7155: Jabulani_Dube
# Processing article 7101/7155: Fletcher_Dulini_Ncube
# Processing article 7102/7155: Ken_Flower
# Processing article 7103/7155: Aguy_Georgias
# Processing article 7104/7155: Sithembile_Gumbo
# Processing article 7105/7155: Josiah_Zion_Gumede
# Processing article 7106/7155: Ellen_Gwaradzimba
# Processing article 7107/7155: Andre_Sothern_Holland
# Processing article 7108/7155: Byron_Hove
# Processing article 7109/7155: Tonderai_Kasu
# Processing article 7110/7155: Wilson_Khumbula
# Processing article 7111/7155: Lovemore_Madhuku
# Processing article 7112/7155: Sarah_Mahoka
# Processing article 7113/7155: Alfred_Makwarimba
# Processing article 7114/7155: Washington_Malianga
# Processing article 7115/7155: Elliot_Manyika
# Processing article 7116/7155: Linda_Masarira
# Processing article 7117/7155: Jevan_Maseko
# Processing article 7118/7155: Anxious_Masuka
# Processing article 7119/7155: Lovemore_Matombo
# Processing article 7120/7155: Bright_Matonga
# Processing article 7121/7155: Isaac_Matongo
# Processing article 7122/7155: Obedingwa_Mguni
# Processing article 7123/7155: Promise_Mkwananzi
# Processing article 7124/7155: Max_Mnkandla
# Processing article 7125/7155: Bekithemba_Mpofu
# Processing article 7126/7155: Earnest_Mudzengi
# Processing article 7127/7155: Mugabe_family
# Processing article 7128/7155: Kisinoti_Mukwazhe
# Processing article 7129/7155: Edwin_Mushoriwa
# Processing article 7130/7155: Munacho_Mutezo
# Processing article 7131/7155: Abel_Muzorewa
# Processing article 7132/7155: Prag_Lalloo_Naran
# Processing article 7133/7155: Owen_Ncube
# Processing article 7134/7155: Nhlanhlayamangwe_Felix_Ndiweni
# Processing article 7135/7155: Gundwane_Ndiweni
# Processing article 7136/7155: Khayisa_Ndiweni
# Processing article 7137/7155: Jane_Ngwenya
# Processing article 7138/7155: Maurice_Nyagumbo
# Processing article 7139/7155: George_Nyandoro
# Processing article 7140/7155: Sekai_Nzenza
# Processing article 7141/7155: Engelbert_Rugeje
# Processing article 7142/7155: Tinos_Rusere
# Processing article 7143/7155: Scot_Sakupwanya
# Processing article 7144/7155: Daniel_Shumba
# Processing article 7145/7155: Maxwell_Zeb_Shumba
# Processing article 7146/7155: Nkululeko_Mkastos_Sibanda
# Processing article 7147/7155: Leopold_Takawira
# Processing article 7148/7155: Gift_Tandare
# Processing article 7149/7155: Rekayi_Tangwena
# Processing article 7150/7155: Temba_Mliswa
# Processing article 7151/7155: Josiah_Tongogara
# Processing article 7152/7155: Langton_Towungana
# Processing article 7153/7155: Sengezo_Tshabangu
# Processing article 7154/7155: Herbert_Ushewokunze
# Processing article 7155/7155: Denis_Walker
# Error Rate: 0.13%

# %% [markdown]
# I've printed each processing article for debugging purposes. Please clear the output if you would not like to see it.

# %% [markdown]
# # 2. Data Processing
#
# ## Overview
# This section involves combining the provided datasets (`population_by_country_AUG.2024.csv` and `politicians_by_country_AUG.2024.csv`, with the ORES Page quality dataset (`ores_quality_scores.csv`) we created in the step above.
#
# In this step, I ran into entries which cannot be merged. The following datasets outputted in the processing step are listed below.
#
# ## Outputs
# - **`wp_countries-no_match.txt`**: Text file of all countries for which there are no matches, with each country on a separate line.
# - **`wp_politicians_by_country.csv`**: The remaining data, with columns for the country,region,	population	article_title,revision_id, and article_quality of each article about a given politician in the provided dataset.

# %%
#Step 3: Combining the Datasets
population_df = pd.read_csv('population_by_country_AUG.2024.csv')
ores_df
# Out:
#                 page_title  revision_id quality_score
# 0           Majah_Ha_Adrif   1233202991         Start
# 1        Haroon_al-Afghani   1230459615             B
# 2              Tayyab_Agha   1225661708         Start
# 3     Khadija_Zahra_Ahmadi   1234741562          Stub
# 4           Aziza_Ahmadyar   1195651393         Start
# ...                    ...          ...           ...
# 7141      Josiah_Tongogara   1203429435             C
# 7142     Langton_Towungana   1246280093          Stub
# 7143     Sengezo_Tshabangu   1228478288         Start
# 7144   Herbert_Ushewokunze    959111842          Stub
# 7145          Denis_Walker   1247902630             C
#
# [7146 rows x 3 columns]

# %% [markdown]
# In these steps I take the steps needed to clean, process, and merge all of our given datasets together.
#
# **Key Steps:**
# - Identify uppercase rows in `population_by_country_AUG.2024.csv` as regions
# - Extract page title from URL
# - Identify unmatched countries in two ways:
#     - 'left_only' to obtain countries in df that have no match in `population_by_country_AUG.2024.csv`
#     - 'right_only' to obtain countries in population_df that have no match in ``politician_by_country_AUG.2024.csv`
# - Save the final merged dataset to `wp_politicians_by_country.csv`.

# %%
population_df['region'] = None  # Add a region column to store the region

current_region = None
for i, row in population_df.iterrows():
    if row['Geography'].isupper():  # Identify uppercase rows as regions
        current_region = row['Geography']
    else:
        population_df.at[i, 'region'] = current_region  # Assign region to country rows

# Remove rows that are regions themselves (we only need countries)
population_df_clean = population_df[population_df['Geography'].apply(lambda x: not x.isupper())]

# Step 1: Extract page_title from URL
df['page_title'] = df['url'].apply(lambda x: x.split("/")[-1])  # Extract page_title from URL

# Step 2: Perform the first merge (df with population_df_clean)
merged_df_1 = pd.merge(df, population_df_clean, left_on='country', right_on='Geography', how='outer', indicator=True)

# Step 3: Identify unmatched countries
# 'left_only' indicates countries in df that have no match in population_df
# 'right_only' indicates countries in population_df that have no match in df

no_match_countries = merged_df_1[merged_df_1['_merge'] != 'both']

with open('wp_countries-no_match.txt', 'w') as f:
    # Log countries in df but not in population_df (left_only)
    left_only_countries = no_match_countries[no_match_countries['_merge'] == 'left_only']['country'].unique()
    f.write("Countries in df but not in population_df:\n")
    for country in left_only_countries:
        f.write(f"{country}\n")

    # Log countries in population_df but not in df (right_only)
    right_only_countries = no_match_countries[no_match_countries['_merge'] == 'right_only']['Geography'].unique()
    f.write("\nCountries in population_df but not in df:\n")
    for country in right_only_countries:
        f.write(f"{country}\n")

# Step 4: Filter out unmatched rows, keep only rows where there's a match
matched_df = merged_df_1[merged_df_1['_merge'] == 'both'].drop(columns=['_merge'])

# Step 5: Perform the second merge 
final_merged_df = pd.merge(matched_df, ores_df, on='page_title', how='left')

# Step 6: Save the final merged dataset 
final_merged_df.to_csv('wp_politicians_by_country.csv', index=False)

# %% [markdown]
# In this step I rename and reorder the columns of our final merged dataframe.

# %%
# Rename columns
final_merged_df = final_merged_df.rename(columns={'name': 'article_title', 'quality_score': 'article_quality', 'Population': 'population'})
final_merged_df.drop('url', axis=1, inplace=True)
final_merged_df.drop('page_title', axis=1, inplace=True)

# Rearrange columns
final_merged_df = final_merged_df[['country', 'region', 'population', 'article_title', 'revision_id', 'article_quality']]
final_merged_df
# Out:
#           country          region  population         article_title  \
# 0     Afghanistan      SOUTH ASIA        42.4        Majah Ha Adrif
# 1     Afghanistan      SOUTH ASIA        42.4     Haroon al-Afghani
# 2     Afghanistan      SOUTH ASIA        42.4           Tayyab Agha
# 3     Afghanistan      SOUTH ASIA        42.4  Khadija Zahra Ahmadi
# 4     Afghanistan      SOUTH ASIA        42.4        Aziza Ahmadyar
# ...           ...             ...         ...                   ...
# 7103     Zimbabwe  EASTERN AFRICA        16.7      Josiah Tongogara
# 7104     Zimbabwe  EASTERN AFRICA        16.7     Langton Towungana
# 7105     Zimbabwe  EASTERN AFRICA        16.7     Sengezo Tshabangu
# 7106     Zimbabwe  EASTERN AFRICA        16.7   Herbert Ushewokunze
# 7107     Zimbabwe  EASTERN AFRICA        16.7          Denis Walker
#
#        revision_id article_quality
# 0     1.233203e+09           Start
# 1     1.230460e+09               B
# 2     1.225662e+09           Start
# 3     1.234742e+09            Stub
# 4     1.195651e+09           Start
# ...            ...             ...
# 7103  1.203429e+09               C
# 7104  1.246280e+09            Stub
# 7105  1.228478e+09           Start
# 7106  9.591118e+08            Stub
# 7107  1.247903e+09               C
#
# [7108 rows x 6 columns]

# %% [markdown]
# ## Data Analysis
#
# ### Overview
# In the analysis section, we examine the distribution and characteristics of the quality scores that can be observed in the merged dataset we created.
#
# My analysis consisted of calculating total-articles-per-capita (a ratio representing the number of articles per person)  and high-quality-articles-per-capita (a ratio representing the number of high quality articles per person) on a country-by-country and regional basis.
#
# For this analysis a "high quality" article are considered to be articles that ORES predicted in either the "FA" (featured article) or "GA" (good article) classes.
#
# The calculated proportions in this step are likely to be very small numbers. This is because the populations that are in `population_by_country_AUG.2024.csv` provides population in millions.
#
# ### Outputs
# We output 6 tables as follows:
# - The 10 countries with the highest total articles per capita
# - The 10 countries with the lowest total articles per capita
# - The 10 countries with the highest high quality articles per capita
# - The 10 countries with the lowest high quality articles per capita
# - A rank ordered list of geographic regions by total articles per capita
# - Rank ordered list of geographic regions by high quality articles per capita

# %%
# Count articles per country
country_article_count = final_merged_df.groupby('country')['article_title'].count().reset_index(name='total_articles')

# Count high-quality articles (FA or GA)
high_quality_df = final_merged_df[final_merged_df['article_quality'].isin(['FA', 'GA'])]
country_high_quality_count = high_quality_df.groupby('country')['article_title'].count().reset_index(name='high_quality_articles')

# Merge article counts with the original data to get population and region
country_stats_df = pd.merge(final_merged_df[['country', 'region', 'population']].drop_duplicates(), 
                            country_article_count, on='country', how='left')

country_stats_df = pd.merge(country_stats_df, country_high_quality_count, on='country', how='left').fillna(0)

# Calculate per capita ratios
country_stats_df['total_articles_per_capita'] = country_stats_df['total_articles'] / country_stats_df['population']
country_stats_df['high_quality_articles_per_capita'] = country_stats_df['high_quality_articles'] / country_stats_df['population']

# aggregate on a regional basis
region_article_count = final_merged_df.groupby('region')['article_title'].count().reset_index(name='total_articles_region')

# Count high-quality articles by region
region_high_quality_count = high_quality_df.groupby('region')['article_title'].count().reset_index(name='high_quality_articles_region')

# Merge region stats
region_stats_df = pd.merge(final_merged_df[['region', 'population']].drop_duplicates(), 
                           region_article_count, on='region', how='left')

region_stats_df = pd.merge(region_stats_df, region_high_quality_count, on='region', how='left').fillna(0)

# Calculate per capita ratios for regions
region_stats_df['total_articles_per_capita_region'] = region_stats_df['total_articles_region'] / region_stats_df['population']
region_stats_df['high_quality_articles_per_capita_region'] = region_stats_df['high_quality_articles_region'] / region_stats_df['population']

# %% [markdown]
# 1. Top 10 countries by coverage: The 10 countries with the highest total articles per capita (in descending order).
#
# Mostly right European islands/countries.

# %%
top_10_by_coverage = country_stats_df[['country', 'total_articles_per_capita']].sort_values(by='total_articles_per_capita', ascending=False).head(10)
top_10_by_coverage
# Out:
#                             country  total_articles_per_capita
# 155                          Tuvalu                        inf
# 99                           Monaco                        inf
# 4               Antigua and Barbuda                 330.000000
# 97   Federated States of Micronesia                 140.000000
# 95                 Marshall Islands                 130.000000
# 150                           Tonga                 100.000000
# 12                         Barbados                  83.333333
# 101                      Montenegro                  63.333333
# 130                      Seychelles                  60.000000
# 92                         Maldives                  55.000000

# %% [markdown]
# 2. Bottom 10 countries by coverage: The 10 countries with the lowest total articles per capita (in ascending order).
#
# Large populous countries. Perhaps GDP is lower?

# %%
bottom_10_by_coverage = country_stats_df[['country', 'total_articles_per_capita']].sort_values(by='total_articles_per_capita').head(10)
bottom_10_by_coverage
# Out:
#            country  total_articles_per_capita
# 32           China                   0.011337
# 66           India                   0.105698
# 57           Ghana                   0.117302
# 127   Saudi Arabia                   0.135501
# 164         Zambia                   0.148515
# 109         Norway                   0.181818
# 70          Israel                   0.204082
# 46           Egypt                   0.304183
# 72   Cote d'Ivoire                   0.323625
# 103     Mozambique                   0.353982

# %% [markdown]
# 3. Top 10 countries by high quality: The 10 countries with the highest high quality articles per capita (in descending order).
#
# GDP high countries? More internet access?

# %%
top_10_by_high_quality = country_stats_df[['country', 'high_quality_articles_per_capita']].sort_values(by='high_quality_articles_per_capita', ascending=False).head(10)
top_10_by_high_quality
# Out:
#                    country  high_quality_articles_per_capita
# 101             Montenegro                          5.000000
# 87              Luxembourg                          2.857143
# 1                  Albania                          2.592593
# 77                  Kosovo                          2.352941
# 86               Lithuania                          2.068966
# 92                Maldives                          1.666667
# 38                 Croatia                          1.315789
# 62                  Guyana                          1.250000
# 112  Palestinian Territory                          1.090909
# 134               Slovenia                          0.952381

# %% [markdown]
# 4. Bottom 10 countries by high quality: The 10 countries with the lowest high quality articles per capita (in ascending order).

# %%
bottom_10_by_high_quality = country_stats_df[['country', 'high_quality_articles_per_capita']].sort_values(by='high_quality_articles_per_capita').head(10)
bottom_10_by_high_quality
# Out:
#                  country  high_quality_articles_per_capita
# 165             Zimbabwe                               0.0
# 115             Paraguay                               0.0
# 59               Grenada                               0.0
# 119                Qatar                               0.0
# 55                Gambia                               0.0
# 122  St. Kitts and Nevis                               0.0
# 123            St. Lucia                               0.0
# 50               Estonia                               0.0
# 49               Eritrea                               0.0
# 48     Equatorial Guinea                               0.0

# %% [markdown]
# 5. Geographic regions by total coverage: A rank ordered list of geographic regions (in descending order) by total articles per capita.

# %%
regions_by_total_coverage = region_stats_df[['region', 'total_articles_per_capita_region']].sort_values(by='total_articles_per_capita_region', ascending=False)
regions_by_total_coverage
# Out:
#               region  total_articles_per_capita_region
# 149          OCEANIA                               inf
# 97    WESTERN EUROPE                               inf
# 125   EASTERN AFRICA                       6730.000000
# 4          CARIBBEAN                       2200.000000
# 93   SOUTHERN EUROPE                       1365.000000
# ..               ...                               ...
# 132  SOUTHERN AFRICA                          2.026359
# 66    SOUTHEAST ASIA                          1.435235
# 72         EAST ASIA                          1.228916
# 65        SOUTH ASIA                          0.473191
# 32         EAST ASIA                          0.108411
#
# [160 rows x 2 columns]

# %% [markdown]
# 6. Geographic regions by high quality coverage: Rank ordered list of geographic regions (in descending order) by high quality articles per capita.

# %%
regions_by_high_quality_coverage = region_stats_df[['region', 'high_quality_articles_per_capita_region']].sort_values(by='high_quality_articles_per_capita_region', ascending=False)
regions_by_high_quality_coverage
# Out:
#               region  high_quality_articles_per_capita_region
# 149          OCEANIA                                      inf
# 97    WESTERN EUROPE                                      inf
# 125   EASTERN AFRICA                               190.000000
# 4          CARIBBEAN                                90.000000
# 93   SOUTHERN EUROPE                                88.333333
# ..               ...                                      ...
# 36     MIDDLE AFRICA                                 0.078201
# 104   WESTERN AFRICA                                 0.058088
# 72         EAST ASIA                                 0.024096
# 65        SOUTH ASIA                                 0.014700
# 32         EAST ASIA                                 0.002126
#
# [160 rows x 2 columns]
